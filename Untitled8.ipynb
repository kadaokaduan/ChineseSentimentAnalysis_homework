# %%
import os
import codecs
import thulac
import re
import numpy as np
from sklearn.svm import SVC
import nltk
import random
import thulac
from sklearn import feature_extraction  
from sklearn.feature_extraction.text import TfidfTransformer  
from sklearn.feature_extraction.text import CountVectorizer  


# 读入情感词典

f= codecs.open('../../sentiment/BosonNLP_sentiment_score.txt',mode='r',encoding='utf-8')
text=f.readlines()
f.close()
senDict ={}
for s in text:
    s=re.sub(r'[\r\t\n\u3000]','',s)
    s=s.split(' ')
    if len(s)==2:
        senDict[s[0]] = np.float_(s[1])

# 否定词
notlist='不、没、无、非、莫、弗、勿、毋、未、否、别、无、休、难道'
notDict=notlist.split('、')

#程度词
f= codecs.open('../../sentiment/degreeAdv.txt',mode='r',encoding='utf-8')
text=f.readlines()
f.close()
degreeDict ={}
for s in text:
    s=re.sub(r'[\r\n\u3000\ufeff]','',s)
    s=re.split('\t',s)
    if len(s)==2:
        degreeDict[s[0]] = np.float_(s[1])
# print(degreeDict)


'''
f=open(r'E:\语言信息处理\stopwords_utf8.txt','r',encoding='utf-8')
raw=f.read()
f.close()
punc=['(',')','，','。','？','“','”','‘','’','：','；','【','】','…','《','■','》','_','<','>','！',',',  '!', '.',  '、', '~', '）', '（', ';', ':']
sent_mark=['，','。','？','！',',',  '!', '.']
stopwords=raw.split()
'''

# 读入文本

def score_sent(sent):
    not_num=0
    degree=1
    score=0
    for w in sent:
        if w in notDict:
            not_num+=1
        if w in degreeDict:
            degree=degree*degreeDict[w]
        if w in senDict:
            score=score+senDict[w]
    score=(-1)**not_num*degree*score
    return score

f=open('../../review_sentiment.v1/train2.rlabelclass','r')
raw=f.read()
f.close()
file_names=raw.split('\n')

file_names=[(f.split(' ')[0], f.split(' ')[1] )for f in file_names if len(f)>0]
random.shuffle(file_names)
file_sent=[s for (f,s) in file_names] #文本的情感标记
files=[f for (f,s) in file_names]   #文件名

thu1= thulac.thulac()
dirname=r"../../review_sentiment.v1/train2/"
sent_doc=[] #句子的情感分值
target=[]   # 句子的人工情感标记
fn=0
fm=0 #正确读入文件数量

for fn in range(len(files)):
    try:
        # f= open(dirname+files[fn],mode='r', encoding="utf-8")
        # raw=f.read()
        f= codecs.open(dirname+files[fn],'r','gb2312')
        text=f.read()
        f.close()
        text=re.sub(r'[\r\n\u3000]','',text)
        sents=re.split('[，。？！,!.\t]',text) #文本切分为句子，依据结束标记和符号
        sents=[s for s in sents if len(s.strip())>0]

        sents_score=[]
        for s in sents:
            words=thu1.cut(s)
            
            words=[w[0] for w in words]
            # print(words)
            words=[w for w in words if ( w in senDict or w in notDict or w in degreeDict )]
            print(words)
            sents_score.append(score_sent(words)) #计算每个句子的情感分值

        #sents_score[-1]=sents_score[-1]*len(sents_score)/2
        sent_doc.append(sum(sents_score))   #每个句子的情感分值的和，作为文本的情感分值
        #sent_doc.append(sents_score[-1])
        
        target.append(file_sent[fn])
        fm+=1
        if fm>2000:
            break
    except:
        continue
# Out:
# Model loaded succeed
# ['是', '新', '的']
# ['到处', '都', '是', '油漆']
# ['房子', '非常', '的', '小']
# ['而且', '地方', '很', '偏僻']
# ['叫', '餐', '不', '错']
# ['大约', '20', '分钟', '能', '到']
# ['就', '是', '菜', '都', '贵']
# ['的', '地毯', '很', '脏']
# ['的', '服务员', '明显', '经过', '培训']
# ['早餐', '我', '建议', '写', '成']
# ['以免', '让', '人', '生气']
# ['还有', '迷你', '吧', '我', '掘', '地', '三', '尺', '找', '不', '到', '在', '哪']
# ['楼下', '那些', '给', '4']
# ['的', '可能', '是', '枪手']
# ['以为', '真', '这', '好', '给', '哄', '来', '了']
# ['原', '来', '…', '…']
# ['不', '信', '大', '就', '知道']
# ['我', '下回', '是', '不', '会', '来', '了']
# ['补充', '点评', '2月', '9日', '：', '还有', '所谓', '的']
# ['是', '普通', '宾馆', '里', '的', '1']
# ['2', '米', '宽', '的', '小', '床']
# ['真', '不', '知道', '如果', '我', '订', '的', '是']
# ['会', '不', '会', '是', '0']
# ['的', '床', '了']
# ['很', '干净']
# ['床', '超大']
# ['热水', '非常', '棒']
# ['赞']
# ['朋友', '都', '非常', '喜欢']
# ['我', '爱', '如', '家']
# ['环境', '级差']
# ['楼道', '弥漫', '着', '种', '难', '闻', '的', '气味']
# ['床单', '被子', '非常', '脏']
# ['家', '具', '电器', '非常', '差']
# ['跟', '本', '人', '来', '维修']
# ['卫生间', '条件', '很', '差']
# ['经常', '热水']
# ['电话']
# ['一切', '非常', '差']
# ['服务', '人员', '根本']
# ['这样', '的', '酒店', '怎', '还', '会', '在', '出现', '呢']
# ['希望', '你们', '总结', '一下']
# ['不', '要', '太', '以', '利益', '为主']
# ['7月份', '刚', '去', '完', '三亚', '回', '来']
# ['都', '是', '住', '在', '仙人掌', '酒店', '的']
# ['感觉', '是', '非常', '不', '错']
# ['给', '人', '休闲']
# ['安静', '的', '感觉']
# ['唯一', '不', '足', '之', '处', '就', '是', '私人', '沙滩', '比较', '远']
# ['其他', '还', '是', '很', '不', '错', '的']
# ['我', '住', '得', '是', '428', '的', '豪华']
# ['第一', '次', '住', '上', '有', '只', '蟑螂']
# ['第二', '次', '住', '时', '门前', '的', '灯罩', '砸', '在', '我', '的', '头', '上']
# ['我', '这', '两', '个', '月', '总共', '住', '了', '近', '20', '天']
# ['有', '天', '我', '问', '报纸', '的', '我', '的', '报纸']
# ['居然', '回答', '我', '说', '：', '工人', '不', '给', '报纸', '的']
# ['（', '我', '刚', '从', '工地', '回', '酒店', '）', '被', '认为', '我', '是', '修', '电梯', '的', '了']
# ['晕']
# ['我', '在', '那', '每天', '消费', '500', '以上']
# ['而且', '住', '那', '长', '时间', '居然', '歧视', '我']
# ['妈', '的']
# ['不', '知道', '怎', '管理', '的']
# ['我', '哪', '天', '肯定', '要', '换', '个', '地方', '住']
# ['位置', '很', '好']
# ['服务', '不', '错']
# ['餐饮', '好']
# ['但', '房', '价', '上升', '太', '了']
# ['当然']
# ['该', '酒店', '有', '一些']
# ['比如', '早餐', '的', '种类', '在', '旅游', '景点', '的', '酒店', '里']
# ['特别', '是', '和', '的', '相比']
# ['已经', '很', '不', '错', '了']
# ['还有', '就', '是', '客房', '服务', '在', '知道', '打开', '房门', '后']
# ['会', '主动', '去', '前台', '帮', '你', '办理']
# ['民航', '大酒店', '的', '设施', '太', '次', '了']
# ['上次', '的', '还', '好', '一点']
# ['勉强', '能', '接受']
# ['此次', '酒店', '说', '预定', '的', '旁', 'KTV', '的', '噪音', '大']
# ['换', '了']
# ['不', '要', '说', '280']
# ['连', '150', '都', '不', '值']
# ['破烂', '陈旧']
# ['比', '我', '住', '过', '的', '任何', '100', '以下', '的', '都', '差']
# ['还', '挂牌', '三星']
# ['装修']
# ['我', '看', '连', '般', '的', '旅馆', '都', '不', '如']
# ['真是', '不', '错', '的', '地方']
# ['好']
# ['好']
# ['好']
# ['但是', '酒店', '的', '服务', '项目', '还要', '增加']
# ['这样', '就', '更', '好', '了']
# ['下次', '去', '我', '还要', '去', '住', '那里']
# ['忘记', '说', '句']
# ['早餐', '太', '差']
# ['品种', '太', '少']
# ['几乎', '东西', '吃']
# ['小米粥', '清', '得']
# []
# ['收费', '是']
# ['可是', '服务', '和', '内容', '是']
# ['比', '招待所', '还', '糟糕']
# ['不', '会', '再', '靠近', '这', '酒店', '了']
# ['总体', '来', '说']
# ['在', '大', '东海', '的', '确', '可以', '算', '最', '好', '的', '酒店', '之一', '了']
# ['其实', '大', '东海', '的', '水', '和', '亚龙湾', '差', '不', '多']
# ['但', '相对', '亚龙湾', '的', '便宜']
# ['而且', '由于', '离', '市区', '比较', '近']
# ['吃喝玩乐', '的', '项目', '都', '比', '亚龙湾', '丰富', '且', '便宜']
# ['酒店', '有', '非常', '漂亮', '的', '花园']
# ['虽', '不', '够', '大']
# ['但', '设计', '巧妙']
# ['增加', '了', '感官', '上', '的', '视觉', '效果']
# ['走', '出', '酒店', '就', '有', '片', '沙滩']
# ['非常', '漂亮', '舒适']
# ['这', '家', '酒店', '的', '硬件', '的', '确', '属于', '度假', '酒店']
# ['不', '同', '于', '酒店', '的', '拘束']
# ['你', '可以', '大胆', '的', '穿着', '泳衣', '或', '沙滩', '走', '在', '酒店', '的', '任何', '角落', '不', '会', '感觉', '怪异']
# []
# ['穿', '着', '在', '这', '家', '酒店', '就', '有', '另', '类', '了']
# ['酒店', '在', '细节', '非常', '细致']
# ['给', '住店', '客人', '带', '来', '很', '大', '的', '和']
# ['如', '酒店', '配备', '了', '专', '为', '客人', '去', '沙滩', '使用', '的', '拖鞋', '和', '大', '毛巾', '(', ')', '及']
# ['一些', '生活', '用品', '用', '颜色', '予以', '区分']
# ['非常', '方便']
# ['穿', '着', '具有', '当地', '特色', '的', '服饰', '的', '酒店', '服务员', '脸上', '始终', '带', '着', '舒心', '的', '微笑']
# ['最', '让', '我', '难忘', '的', '是', '在', '楼', '花园', '自助', '晚餐', '时']
# ['品', '着']
# ['听', '着', '美妙', '的', '旋律']
# ['吹', '着', '舒适', '的', '海风', '分享', '了', '朋友', '的', '生日']
# ['相信', '下次', '去', '三亚', '还', '会', '选择', '这里']
# ['这', '是', '我', '住', '过', '这', '多', '酒店', '中', '最', '好', '的', '家']
# ['我', '住', '过', '的', '酒店', '从', '三星', '到', '五星', '的', '都', '有']
# ['可', '这', '家', '酒店', '就', '像', '大', '家', '说', '的', '那样']
# ['什', '可', '挑剔', '的']
# ['多', '了', '不', '说']
# ['只有', '亲自', '住', '才', '能', '体会', '出', '来']
# ['交通', '很', '方便']
# ['沪', '杭', '下', '来', '后', '一直', '走', '就', '可以', '到达']
# ['楼下', '就', '是', '商场']
# ['有', '酒', '吧', '有']
# ['有', '酒店']
# ['价', '格', '不', '算', '贵']
# ['去', '景区', '和', '闹市区', '都', '很', '方便']
# ['安全', '好']
# ['忘', '在', '里', '费', '了', '很', '长', '时间', '才', '给', '开门']
# ['这', '是', '负责', '呀']
# ['敢于', '对', '自己', '存在', '的', '错误', '承担']
# ['这', '是', '的', '优点']
# ['是', '我', '喜欢', '去', '浙江', '的', '理由']
# ['如果', '能够', '宽敞']
# ['那', '就', '的', '地方', '的', '理由', '了']
# ['位置', '好', '；', '服务', '好', '；', '小']
# ['但', '人', '没', '问题']
# ['水平', '有待', '提高']
# ['对', '环境', '了', '解', '太', '少']
# ['交通', '方便']
# ['外观', '漂亮']
# ['早餐', '不错']
# ['只', '是', '酒店', '不', '是', '很', '新']
# ['很', '好', '的', '酒店']
# ['服务', '态度', '很', '好']
# ['可以', '可以', '免费', '上网']
# ['而且', '价', '格', '较为', '合理']
# ['不', '足', '的', '是', '标准', '的', '单人', '(', ')', '的', '太', '小']
# ['洗浴', '间', '更', '小']
# ['洗澡', '时', '很', '不', '方便']
# ['大']
# ['服务', '及', '不', '规范']
# ['电视', '节目', '少']
# ['硬件', '有', '老', '了']
# ['不', '过', '1', 'k', '以下', '的', '价格']
# ['希尔顿', '的', '名声']
# ['算', '不', '错']
# ['环境', '非常', '好']
# ['临街']
# ['但', '不', '吵']
# ['值']
# ['我', '住', '的', '是', '公寓']
# ['有', '厨房']
# ['还有', '冰箱']
# ['卫生', '不错']
# ['暖气', '非常', '给', '劲']
# ['很', '满意']
# ['进', '就', '有', '股', '异味', '扑鼻', '而', '来']
# ['很', '小', '且', '肮脏', '不', '堪']
# ['更', '可恶', '的', '是', '床', '上', '不', '干净']
# ['床单', '被', '斑斑']
# ['前台', '接待', '小姐', '满', '口', '四川', '话']
# ['态度', '极其', '恶劣']
# ['第二', '天', '我', '离', '店', '的', '时候', '在', '了', '解', '到', '在', '的', '上', '还', '可以', '打折']
# ['连', '这样', '的', '招待所', '都', '挂', '在', '网上', '欺骗', '广大']
# ['诚信', '缺失']
# ['返', '家', '后']
# ['特意', '在', '此']
# ['以', '警示', '广大']
# ['以免', '有人', '再', '上当']
# ['非常', '舒适', '整洁']
# ['服务', '很', '好']
# ['就', '在', '城墙', '边']
# ['可以', '赏']
# ['下次', '还', '来', '住']
# ['我', '通过', '为', '公司', '客人', '订', '了', '间', '豪华', '间']
# ['并', '已', '付', '了', '订金']
# ['可', '晚上', '客人', '入住', '时', '前台', '在', '良好', '查证', '的', '情况', '下', '即', '作', '否', '定', '答复']
# ['并', '与', '我方', '客人', '发生', '争执']
# ['耽误', '入', '住', '半', '个', '多', '小时']
# ['虽', '事后', '提出', '道歉']
# ['但', '对', '客人', '造成', '非常', '坏', '的', '印象']
# ['影响', '了', '我们', '公司', '的', '形象']
# ['浴巾', '还', '是', '破', '的']
# ['吃得消', '吗', '你', '说']
# ['酒店', '正在', '大', '装修']
# ['楼层', '的', '过道', '地毯', '上', '铺', '着', '塑料纸']
# ['民工', '在', '各', '楼层', '席地而坐']
# ['更', '可气', '的', '是', '的', '都', '拆', '了']
# ['用', '木板', '封', '着']
# ['外面', '就', '是', '脚手架']
# ['可以', '清楚', '听到', '窗外', '工人', '走动', '和', '说话', '声音']
# ['可怕', '啊']
# ['麻烦', '大修', '时', '就', '暂停', '营业', '嘛']
# ['卫生', '状况', '令', '人', '满意']
# ['服务', '周到']
# ['对', '个人', '彬彬有礼']
# ['印象', '不', '错']
# ['什', '三', '星', '真', '叫', '后悔', '地毯', '都', '不', '叫', '地毯', '上面', '好多', '黑色', '烟头', '烫', '的', '洞']
# ['里', '的', '设施', '严重', '老化', '电视', '的', '遥控器', '正常', '工作', '跟', '楼层', '的', '值班', '人员', '要', '了', '结果', '还是', '一样', '闷', '热水', '到', '10点', '就', '没', '了', '打电话', '去', '问', '他们', '说', '要']
# ['结果', '等', '了', '晚上']
# ['交通', '很', '是', '不', '方便', '打', '个', '车', '很', '难']
# ['真', '不', '明白', '怎', '会', '让', '这种', '垃圾', '进入', '呢', '以后', '对', '他们', '没', '什', '信心', '了']
# ['没', '见', '过', '这', '差', '的', '4', '星', '北京', '旅游', '管理局', '不', '知道', '怎', '评', '的', '星']
# ['元', '包', '双', '早', '入', '住']
# ['位置', '好']
# ['去', '外滩', '方便']
# ['在', '落地窗', '前']
# ['看到', '了', '远处', '的', '金茂', '大厦']
# ['补充', '点评', '2006年', '10月', '24日', '：', '1000', '元', '左右', '价', '格', '刚好']
# ['再', '高', '就', '不', '值', '了']
# ['整体', '条件', '和', '希尔顿']
# ['花园']
# ['东方', '不', '多']
# ['在', '意大利', '最后', '悔', '的', '就', '是', '住', '了', '这', '家', '酒店']
# ['建议', '不', '要', '把', '这种', '垃圾', '酒店', '放', '上', '来']
# ['既', '损害', '消费者']
# ['对', '的', '声誉', '不', '好']
# ['我', '原', '来', '定', '的', '是']
# ['床']
# ['到', '酒店', '后']
# ['给', '我', '的', '是', '５']
# ['３', '个', '床']
# ['介绍', '说', '是', '墙上', '挂', '了', '画']
# ['但', '空空', '的']
# ['空调']
# ['卫生间', '又', '差']
# ['还', '漏水']
# ['可', '简直', '就', '比', '国内', '的', '招待所', '都', '不', '如']
# ['价', '要']
# []
# ['找', '前台', '服务员']
# ['用']
# ['只', '有', '这', '间', '房']
# ['要', '不', '是', '付', '了', '钱', '给']
# ['就', '是', '免费', '给', '我']
# ['都', '嫌', '差']
# ['而且', '这个', '酒店', '竟然', '自己', '的', '电梯', '和', '楼梯']
# ['全都', '和', '隔壁', '的', '酒店', '共', '用', '部', '电梯']
# ['酒店', '真', '的', '很', '不', '错']
# ['每次', '来', '烟台', '都', '是', '住', '这里']
# ['虽然', '宾馆', '外观', '比较', '不', '起', '眼']
# ['但是', '内部', '的', '软', '硬件', '绝对', '是', '很', '不', '错', '的']
# ['这', '次', '入住']
# ['早餐', '非常', '不', '错']
# ['很', '~', '~', '~', '~', '~', '~', '~', '~', '~', '~', '~', '~', '~', '~', '比', '济南', '索菲特', '的', '都', '强']
# ['住', '过', '了']
# ['挺', '失望', '的']
# ['房', '价', '小']
# ['仅', '暖风机', '没', '制冷', '空调']
# ['夏天', '去', '一定', '受', '不', '了']
# ['唯一', '优点', '离', '地铁']
# ['但', '巴黎', '的', '地铁', '很多']
# ['几乎', '没', '多', '远', '总', '会', '遇到', '个', '地铁站']
# ['从', '戴高乐', '机场']
# ['再', '转', 'M2', '在', '9', '即', '可以', '到达']
# ['时间', '在', '1']
# ['5', '小时', '左右']
# ['态度', '还', '行']
# ['能', '说', '英语']
# ['本', '来', '我', '是', '订', '有', '窗户', '的']
# ['但', '前台', '小姐', '竟', '说', '有', '窗户', '的', '了']
# ['给', '我', '换', '了', '窗户', '的']
# ['胡闹', '啊']
# ['还有']
# ['早餐', '的', '东西', '太', '少']
# ['其它', '般']
# ['上网', '免费']
# ['速度']
# ['稳定']
# ['除', '了', '卫生间']
# ['各', '都', '不', '错']
# ['我', '住', '的', '1802']
# ['大', '家', '尽量', '不', '要', '选', '了']
# ['这个', '的', '浴缸', '有', '破', '了']
# ['还是', '看看', '其他', '吧']
# ['该', '酒店', '目前', '状况', '连', '小', '客栈', '都', '不', '如']
# ['在', '改扩建', '阶段', '根本', '就', '不', '该', '营业']
# ['外部', '环境', '脏乱']
# ['客房', '中', '蚊子', '数量', '巨大']
# ['最', '多', '的', '客房', '中', '消灭', '了', '30', '只', '以上', '的', '蚊子']
# ['设施', '老', '旧']
# ['建议', '将', '其', '暂时', '挂', '起']
# ['待', '其', '后', '再', '入住']
# ['总体', '还', '符合', '评定', '的', '星级', '标准']
# ['没', '什', '好', '挑剔', '的']
# ['周围', '很', '热闹']
# ['很', '可以', '的', '酒店']
# ['和', '深圳', '其他', '酒店', '相比']
# ['它', '值得', '推荐']
# ['算是']
# ['还', '可以', '了']
# ['只是', '到', '虹桥', '比较', '近', '才', '选择', '这个', '酒店', '入', '住', '的']
# ['270', '元', '的', '标准', '间']
# ['房', '价', '是', '不', '含', '早餐', '的']
# ['check', 'i', 'n', '的', '时候', '问', '他们', '早餐', '在', '什', '地方', '可以', '吃']
# ['服务员', '：', '10', '元', '位']
# ['外面', '街上', '有', '的', '吃', '啊']
# ['周围', '都', '有', '的']
# ['进去', '地毯', '是', '脏', '的']
# ['空气', '很', '陈旧']
# ['由于', '离', '汽车站', '很', '近']
# ['所以', '窗户', '都', '是', '被', '锁', '住', '的']
# ['要', '找', '服务员', '拿', '钥匙']
# ['很', '闷']
# ['空调', '最', '大', '都', '不', '制冷']
# ['问', '了', '服务员']
# ['第一', '个', '很', '生硬', '说', '就', '是', '没', '空调']
# ['只有', '吹风']
# ['我', '说', '要', '投诉']
# ['要', '去', '投诉']
# ['什', '三星级', '酒店', '~']
# ['第二', '个', '服务员', '给', '我', '打电话', '的', '时候', '态度', '好', '了', '很多']
# ['说', '为', '了', '节电']
# ['政府', '明令禁止', '在', '30', '度', '以下', '开', '空调']
# ['5', '6', '当天', '是', '28', '度']
# ['所以', '还', '不', '能', '开']
# ['绍兴', '是', '这样', '的']
# ['所以', '要', '给', '个', '电风扇']
# ['然后', '开', '窗']
# ['然后', '着', '电', '蚊香']
# ['我', '气', '得', '不', '打', '处', '来']
# ['质问', '他们', '怎', '评', '的', '三星']
# ['服务', '和', '态度', '都', '这', '差']
# ['我', '在', '绍兴', '怎', '没', '听说', '这种', '理论', '呢']
# ['我', '让', '他们', '经理', '和', '我', '说']
# ['结果', '经理', '保证', '说', '晚上', '7点', '会', '开', '空调']
# ['与', '是', '争论', '告一段落']
# ['晚上', '8点', '回到', '酒店']
# ['还是', '闷热']
# ['打电话', '过去', '问']
# ['说', "'", '开', '了', '呀']
# ['怎', '没', '开', '呢']
# ['再', '去', '问问', '经理', '吧', '~', '~', "'", '昏', '死', '~']
# ['为', '了', '安全', '起见']
# ['还是', '关', '了', '窗户', '、', '要', '了', '电风扇', '和', '香片']
# ['第二', '天', 'check', 'out']
# ['服务员', '把', '一对', '单据', '扔', '给', '我', '就', '完', '了']
# ['从头到尾', '没', '说', '两', '句', '话']
# ['我', '等', '了', '半天', '问', '她', '是', '不', '是', 'ok', '了']
# ['她', '头', '不', '抬', '说', '：', '嗯']
# ['服务', '~']
# ['想起', '来', '就', '火大']
# ['有点', '小', '灯光', '又', '不', '够', '亮', '整体', '环境', '差强人意']
# ['一切', '都', '没', '变']
# ['还', '是', '那', '舒适', '的']
# ['那', '美丽', '的', '海景']
# ['值得', '怀念']
# ['The', 'hotel', 'i', 's', 'okay', 'and', 'room', 'i', 's', 'pretty', 'small', 'b', 'u', 't', 'I', 'really', 'i', 't', 'and', 'I', 'guess', 'I', 'would', 'stay', 'i', 'n', 'for', 'next', 'time']
# ['本', '酒店', '另', '我', '非常', '满意']
# ['酒店', '的', '服务', '\\', '设施', '还', '是', '酒店', '的', '价格', '\\', '地理', '位置']
# ['很', '不', '错']
# ['出差', '首选']
# ['不', '算', '贵']
# ['希望', '设备', '要', '经常', '检修', '啊']
# ['最', '好', '纯净水', '就', '好', '了']
# ['酒店', '不', '错', '我', '常常', '住']
# ['但', '最近', '数码', '房', '取消', '了', '无', '烟', '就', '不', '方便', '了']
# ['This', 'i', 's', 'a', 'ver', 'y', 'hotel']
# ['Nice', 'rooms']
# ['very', 'with', 'both', 'and', 'separate', 'shower']
# ['Lovely', 'Chinese', 'painting', '-']
# ['Nice', 'buffet', 'breakfast', 'for', 'yuan']
# ['Very', 'good', 'service']
# ['very', 'clean']
# ['Great', 'location', 'a', 't', 'the', 'ver', 'y', 'top', 'of', 'F', 'u', 'Jing']
# ['The', 'staff', 'i', 's', 'all', 'new', 's', 'o', 'i', 's', 'still', 'a']
# ['but', 'they', 'all', 'very', 'hard', 'and', 'i', 't', 'shows']
# ['想', '不', '到', '会', '与', '这', '家', '酒店', '合作']
# ['、', '环境', '等', '太', '旧', '了']
# ['最', '多', '能', '算', '上', '个', '招待所']
# ['而且', '刷', '不', '了', '、', '退', '房', '时', '不', '能', '寄存', '行李']
# ['其他', '都', '过得去']
# ['唯有', '所谓', '的', '所有', '都', '有', '宽带', '比较', '过分']
# ['有', '是', '有']
# ['收费']
# ['收费', '就', '收费', '吧']
# ['好贵']
# ['6', '毛', '钱', '分钟']
# ['抢', '钱', '啊']
# ['现在', '还有', '哪', '个', '酒店', '上网', '要', '收费', '啊']
# ['住', '过', '次']
# ['再', '不', '会', '去', '了']
# ['还有', '我', '住', '的', '是', '套房']
# ['的']
# ['空调', '只有', '和']
# ['下边', '冷', '的', '要', '死']
# ['不', '错', '的', '酒店']
# ['实在']
# ['各', '都', '值得', '推荐']
# ['而且', '最后', '的', '房', '价', '比', '订', '价', '要', '低']
# ['这次', '相当', '圆满']
# ['酒店', '18', '后', '入住', '需要', '信用卡', '担保']
# ['所以', '我', '当天', '才', '订']
# ['订', '的', '要']
# ['回复', '说', '大', '床', '了']
# ['双', '床', '行']
# ['只好', '同意']
# ['但', '到', '酒店', '后']
# ['我', '说', '请', '尽量', '安排']
# ['前台', '服务员', '满足', '了', '我', '的', '要求']
# ['给', '我', '免费', '升级', '为', '套房']
# ['卧室', '窗户', '对', '中央', '大街']
# ['酒店', '服务', '很', '好']
# ['早餐', '喜欢', '的', '很', '值']
# ['如果', '不', '喜欢', '就', '不', '推荐', '了']
# ['交通', '\\', '位置', '一级', '棒']
# []
# ['除', '了', '地理', '位置']
# ['实在', '不', '怎', '样', '啊']
# ['的', '议', '价', '能力', '实在', '太', '差', '了']
# ['入住', '时', '一定', '要', '选', '好']
# ['服务', '不', '错']
# ['大堂', '差', '了', '些']
# ['进', '们', '时', '在', '候诊']
# ['的']
# ['位置', '不', '错']
# ['在', '海边', '的', '山上']
# ['远眺', '视野', '还', '很', '开阔']
# ['离', '市中心', '很', '近']
# ['设施', '还', '很', '新']
# ['服务', '还', '不', '错']
# ['早餐', '还', '可以']
# ['综合性', '价', '比', '应该', '比', '我', '住', '的', '那', '间', '五星', '的', '要', '好']
# ['一流', '地点', '二流', '服务', '设施']
# ['住', '的', '是']
# ['很', '大']
# ['很', '干净']
# ['床', '很']
# ['浴室', '很', '大']
# ['总体', '的', '设计', '我', '很', '满意']
# ['酒店', '服务', '人员', '态度', '还', '可以']
# ['问', '了', '大堂', '经理', '武汉', '的', '一些', '特色']
# ['很', '耐心', '细心', '的', '告诉', '了', '我们']
# ['表示', '感谢']
# ['下次', '来', '武汉', '还', '会', '住', '这里']
# ['国庆', '期间', '入住', '感觉', '还', '可以']
# ['598', '的', '间', '即', '可见', '园林']
# ['家', '具', '较', '新']
# ['服务', '尚', '可', '不', '足', '：', '1', '、', '门口', '在', '修路']
# ['打车', '不', '方便', '2', '、', '阳台', '的', '椅子', '和', '茶几', '从', '来', '人', '擦洗', '过']
# ['可能', '从', '来', '就', '没', '人', '敢', '坐']
# ['冤枉', '了', '面对', '长安街', '的', '好', '风景']
# ['3', '、', '的', '家具', '太', '旧']
# ['有', '异味']
# ['Five', 'stars', 'service', 'and', 'central']
# ['住', '过', '这', '差', '的', '五星级', '酒店']
# ['就', '像', '三星级', '的']
# ['进', '门', '就', '有', '股']
# ['好像', '很', '久', '没', '人', '住', '过', '一样']
# ['卫生间', '很', '差']
# ['不', '知', '这', '家', '五星级', '是', '如何', '评', '上', '的', '1']
# ['1']
# []
# ['酒店', '走廊', '都', '手机', '信号']
# ['2']
# ['酒店', '上网', '需', '重新', '设', 'IP', '地址']
# ['前台']
# ['待', '到', '客户', '不', '能', '上网', '时']
# ['客户', '通过', '查询', '才', '知晓']
# ['管理', '不', '到位']
# ['服务', '无', '程序']
# ['3']
# ['空调', '事先', '插', '电源']
# ['电源', '插座', '的', '位置', '很', '高']
# ['至少', '应该', '在', '客户', '入', '住', '前', '插', '好']
# ['4']
# ['是', '封闭', '空间']
# ['唯一', '的']
# ['空气', '不', '好']
# ['5']
# ['床', '上', '的', '被单', '和', '被子', '有', '股']
# ['可能', '很', '久', '人', '住']
# ['客人', '入住', '前', '不', '仔细', '打扫', '检查']
# ['更换', '干净', '些', '的']
# ['我', '住', '的', '是', '别墅区']
# ['没', '的', '说']
# ['环境', '好']
# ['不', '过', '太', '好']
# ['又', '有', '免费', '上网']
# ['让', '人', '觉得', '只是', '晚上', '回去', '睡觉', '太', '浪费', '了']
# ['不', '是', '喜欢', '晚上', '吧', '就', '不', '那', '方便']
# ['（', '晚上', '打', '的', '15', '元', '）']
# ['条件', '太', '差', '了']
# ['和', '毛巾', '等', '设施', '都', '不', '干净']
# ['420', '居然', '门缝', '有']
# ['怕', '怕']
# ['服务', '态度', '好']
# ['宽大']
# []
# ['就', '是', '好像', '比较', '少']
# ['连', '续', '的', '空房']
# ['该', '宾馆', '交通', '便利']
# ['环境', '幽雅']
# ['闹', '中', '取', '静']
# ['设施', '略', '显', '陈旧']
# ['但', '服务', '温馨']
# ['尤其', '卫生', '很', '不', '错', '让', '人', '感觉', '很', '干净', '的']
# ['唯一', '美中不足', '处', '是', '早餐', '品种', '单一']
# ['口味', '欠佳']
# ['差']
# ['达', '不', '到', '标准']
# ['价', '钱', '还', '很', '贵']
# ['洗手间', '居然', '牙具']
# ['后', '来', '由', '服务员', '一一', '来']
# ['很', '旧']
# ['不', '过', '很', '大']
# ['入住', '和', '退', '房', '都', '等', '了', '很', '久']
# ['下次', '决', '不', '会', '再', '住']
# ['服务', '很', '好']
# ['非常', '满意']
# ['下次', '还', '会', '入', '住', '该', '酒店', '的']
# ['前台', '服务', '特别', '好']
# ['替', '客人', '着想']
# ['酒店', '的', '环境', '很', '好']
# ['服务', '很', '周到']
# ['我', '很', '喜欢']
# ['这', '差', '的', '宾馆', '怎', '会', '有', '3', '星']
# ['网速', '我', '测', '了', '下', '是', '56', 'k']
# ['哈', '猫', '啊']
# ['因为', '回', '学校', '的', '车', '所以', '晚上', '11点', '才', '急匆匆', '向', '的']
# ['因为', '电话', '服务员', '说', '这', '家', '酒店', '评', '价', '不错', '才', '预先', '定下', '来']
# ['是', '学生', '又', '是', '住', '晚上', '所以', '就', '选', '了', '延安路', '上', '便宜', '的', '家']
# ['要', '信用卡', '担保', '才', '能', '预定', '的']
# ['快要', '走', '完', '整', '条', '延安路', '的', '时候', '才', '看', '这', '家', '一点', '都', '没', '办法', '被', '看做', '三星级', '的', '酒店']
# ['走', '到', '大门口', '就', '失望', '了']
# ['预先', '缴费', '的', '时候', '居然', '不', '能', '刷', '~', '真是', '晕', '菜']
# ['我们', '身上', '又']
# ['几', '经', '交涉', '才', '同意', '我们', '把', '身份证', '押', '在', '前台', '才', '让', '我们', '入住']
# ['看到', '的', '时候', '就', '更', '失望', '了']
# ['我们', '定', '的', '时候', '是', '标准', 'A', '(', '240', 'RMB', ')']
# ['是', '我', '住', '过', '能', '称', '的', '上', '三星级', '的', '最', '小', '的']
# ['卫生间', '我', '都', '不', '要', '走', '进']
# ['一塌糊涂']
# ['脏', '的', '要', '死']
# ['设施', '很', '简单']
# ['这样', '能', '算', '的', '上', '是', '?', '那里', '的', '环境', '对于', '休息', '是', '绝对', '不', '好', '的']
# ['晚上', '我', '到', '2点', '才', '睡', '着']
# ['一大早', '大概', '6', '的', '时候', '又', '被', '周围', '的', '声音', '吵', '醒', '了']
# ['早饭', '没', '去', '吃']
# ['这', '家', '酒店', '收', '的', '价格', '和', '实际', '一点', '都', '不', '符']
# ['算', '的', '上', '是', '差差', '酒店', '之一', '了']
# ['我', '住', '过', '很多', '酒店']
# ['感觉', '这', '家', '希尔顿', '是', '个', '标准', '的', '酒店']
# ['而且', '档次', '很', '好', '了']
# ['硬件', '设备', '非常', '不', '错']
# ['洗手', '间', '豪华', '的', '很', '啊']
# ['洗澡', '非常']
# ['位置', '虽然', '不', '如', '解放碑', '旁边', '的', '万豪']
# ['但是', '是', '渝中区', '这样', '的', '好', '地方']
# ['加上', '价', '钱', '这', '便宜']
# ['足', '可以', '啦']
# ['昆明', '最', '好', '的', '酒店']
# ['是', '我', '最', '喜欢', '的', '酒店', '之一']
# ['每次', '来', '昆明']
# ['翠湖', '一直', '是', '我', '不', '的', '选择']
# ['矿泉水', '是', '的']
# ['我', '真是', '闻所未闻', '哪']
# ['刚才', '携', '城', '的', '还', '给', '我', '电话']
# ['表示', '酒店', '会']
# ['下次', '再', '住', '果盘']
# ['但是', '要', '把', '我', '的', '点评', '删除']
# ['是', '有', '诚意']
# ['果盘', '呢']
# ['我', '前', '时', '已经', '过']
# ['那', '是', '在', '住店', '2', '个', '小时', '之后']
# ['并', '不', '象', '其他', '客人', '说', '的', '那样']
# ['立即', '上']
# ['我', '就', '打', '了', '电话', '自己', '去', '索要']
# ['吃', '还', '好']
# ['估计', '是', '切', '水果', '的', '刀具', '不', '干净']
# ['那天', '晚上', '2', '次', '腹泻']
# ['因为', '是', '出丑', '了']
# ['所以', '没', '写', '上']
# ['今天', '告诉', '大', '家']
# ['他们', '还要']
# ['我', '说', '谢谢']
# ['但是', '打', '死', '我', '不', '吃', '了']
# ['当然']
# ['不', '会', '去', '住']
# ['如果', '他们', '要', '删除', '我', '写', '的', '这些']
# ['我', '意见']
# ['但是', '如果', '他们', '是', '这样', '蒙骗', '客户', '住', '酒店', '的', '话']
# ['估计', '生意', '很', '难', '做', '大']
# ['这', '是', '中国', '公司', '的', '宿命']
# ['非常', '干净']
# ['宾馆', '在', '杭州', '火车站', '（', '当地人', '叫', '“', '”', '）', '的']
# ['不', '在']
# ['如果', '您', '坐', '火车', '的', '话', '特别', '方便']
# ['值得', '住']
# ['但是', '宾馆', '的', '宽带', '稍', '为', '慢', '一点儿']
# ['住', '了', '星期', '高级', '房']
# ['除', '了', '隔音', '稍', '差']
# ['其它', '都', '很', '满意']
# ['装修', '很', '新']
# ['服务', '很', '细心']
# ['三', '楼', '的', '潮州']
# ['刚', '开幕']
# ['好吃']
# ['非常', '让', '人', '失望']
# ['check', 'i', 'n', '和', 'check', 'out', '都', '等', '了', '很', '长', '时间']
# ['效率', '可言']
# ['宽带']
# ['去', '中心', '5', '元', '每', '小时']
# ['抢', '钱']
# ['设施', '老', '的', '很']
# ['真', '的', '不', '配', '5', '星']
# ['弄', '个', '2', '-', '准', '3', '星', '还', '差', '不', '多']
# ['前台', '收银', '服务', '态度', '很', '不', '好']
# ['很', '差', '的', '酒店']
# ['所有', '的', '下水', '排泄', '不', '畅', ';', '冷气', '不', '足']
# ['酒店', '整体', '感觉', '档次', '较', '高']
# ['我', '订', '的', '有', '免费', '宽带', '上网', '的', '电脑']
# ['非常', '方便']
# ['地理', '位置', '相当', '不', '错']
# ['的', '确', '就', '在', '旁边']
# ['离', '地铁站', '步行', '三', '分钟']
# ['酒店', '位置', '相当', '不', '错']
# ['离', '南京路', '淮海路', '近']
# ['进出', '很', '方便']
# ['酒店', '服务', '和', '设施', '都', '不', '错']
# ['很', '干净']
# ['就是', '价', '便宜', '些', '就', '更', '好', '了']
# ['五一', '黄金周', '入', '住', '的', '设施', '般']
# ['宽带', '竟然', '是', '收费', '的']
# ['整体', '设施', '不', '孩子', '去', '还是', '很', '理想', '的']
# ['服务', '态度', '值得', '表扬']
# ['建议', '相关', '游乐', '设施', '的', '收费', '应该', '更', '合理', '些', '譬如', '50', '元', '次', '的', '和', '50', '元', '次', '的', '射击', '项目']
# ['交通', '到', '西湖', '出租车', '大约', '在', '26', '元']
# ['作为', '还是', '可以', '接受', '的']
# ['的', '如果', '整理', '一下', '的', '话', '就', '会', '更', '好']
# ['该', '酒店', '环境', '舒适']
# ['干净', '卫生']
# ['各', '的', '细节', '都', '做', '得', '不', '错']
# ['服务', '很', '周到']
# ['酒店', '的', '环境', '幽雅', '大气']
# ['各方', '的', '服务', '周到', '热情']
# ['若', '能', '对', '的', '不同', '层次', '会员', '给', '予', '不', '同', '的', '价格', '优惠']
# ['则', '更', '能', '激励', '入', '住', '索菲特', '之', '激情']
# ['还有', '值得', '提', '一下']
# ['酒店', '的', '的', '床', '超', '大', '、']
# ['足', '有', '2', '米']
# ['在', '上面', '斗', '都', '行', '啊']
# ['非常', '值得', '推荐']
# ['这个', '宾馆', '的', '环境', '非常', '好']
# ['园林式', '的']
# ['据说', '亚洲', '最', '大']
# ['有', '5', '星']
# ['4', '星']
# ['公寓', '可', '选']
# ['非常', '好']
# ['是', '中关村', '的', '闹市']
# ['方便']
# ['前台', '的', '服务', '太', '恶劣', '了', '：', '我', '是', '4月', '28日', '到', '13日', '入', '住', '酒店', '的']
# ['在', '5', '-', '的', '晚上', '我', '喝', '多', '了', '酒', '结果', '呕', '吐', '了']
# ['在', '5', '-', '9', '到', '5', '-', '13', '只见', '我', '没', '接到', '酒店', '的', '任何', '反应']
# ['结果', '在', '5', '-', '13日', '我', '退', '房', '其间', '他们', '突然', '说', '要', '收', '我', '51', '元', '毛巾', '的']
# ['（', '其实', '我', '根本', '就', '不', '知道', '是', '不', '是', '真', '的', '有', '呕', '吐', '在', '他们', '酒店', '的', '毛巾', '上']
# ['就算', '真', '的', '有', '呕', '吐', '在', '他们', '的', '毛巾', '上', '他们', '是', '否', '应该', '在', '第二', '天', '通知', '我', '呢']
# ['）', '我', '当时', '是', '非常', '不', '愿意', '交', '这', '51', '元', '的']
# ['当时', '因为', '我', '当时', '时间', '很', '紧迫']
# ['不', '得', '已', '被', '了', '这', '51', '元']
# ['希望', '能', '帮', '我', '把', '51', '元', '钱', '要', '回', '来']
# ['然后', '我', '再', '加', '950', '元', '一起', '捐', '给', '山区', '学校']
# ['谢谢']
# ['在', '这', '其间']
# ['跟', '我', '解释', '这', '件', '事情', '的', '态度', '是', '非常', '恶劣', '的']
# ['说话', '的', '语气', '非常', '的', '强硬', '让', '我', '很', '难', '接受']
# ['还有']
# ['如果', '是', '需要', '上', '宽', '带', '的', '朋友', '我', '建议', '你们', '千万', '考虑', '一下', '网络', '问题', '：', '在', '我', '入住', '的', '其间', '他们', '酒店', '的', '网络', '经常', '不', '能', '上']
# ['然后', '叫', '他们', '的', '来', '看', '一下']
# ['结果', '是', '他们', '的', '是', '按照', '正常', '时间', '上班', '的']
# ['要是', '在', '18', '：', '00', '-', '0', '9', '：', '00', '之前', '你', '的', '网络', '坏', '了', '那', '你', '只能', '等', '了']
# ['更', '可笑', '的', '居然', '还']
# ['本', '来', '我', '还', '得', '再', '住', '很多', '天', '的']
# ['结果', '我', '是', '5', '-', '1', '2', '号', '晚上', '22', '：', '00', '发现', '网络', '坏', '了', '上', '不', '了']
# ['打电话', '给', '客房', '服务']
# ['他们', '说', '电脑房', '休息', '得', '明天', '上班', '后', '再', '叫', '他们', '来', '看', '一下']
# ['好', '不', '等', '到', '第二', '天', '早上', '09', '：', '30', '我', '再', '打电话', '给', '他们']
# ['他们', '居然', '告诉', '我', '说', '今天', '星期六', '电脑房', '不', '上班']
# ['（', '我', '当时', '急', '着', '发', '几', '邮件']
# ['不', '得', '已', '只能', '上网', '吧', '了']
# ['）', '我', '在', '那里', '住', '了', '那', '多', '天', '大', '家', '千万', '别', '误会', '是', '酒店', '不', '错']
# ['其实', '是', '我', '的', '行李', '太', '多']
# ['我', '住', '进去', '了', '就', '懒', '的', '搬', '第二', '家']
# ['挺', '不', '错', '的', '酒店']
# ['提', '几', '小', '意见']
# ['洗浴', '用具', '中']
# ['隔音', '设备', '不', '太', '好']
# ['听', '得到', '隔壁', '卫生间', '的']
# ['再', '有']
# ['就', '是', '太', '热情']
# ['有点', '不', '太', '习惯']
# ['总', '的', '来说']
# ['挺', '不', '错', '的']
# ['以后', '来', '长沙', '的', '话']
# ['还', '会', '选择', '这里']
# ['上个月']
# ['从', '欧洲', '回', '来', '的', '第一', '晚']
# ['就', '和', '朋友', '入', '住', '了', '宾馆']
# ['我', '是', '住', '在', '杭州', '的']
# ['不', '过', '还是', '经常', '宾馆', '住', '几', '天']
# ['周末', '在', '西湖', '两', '天', '假']
# ['的', '美景']
# ['妙不可言']
# ['的', '电视', '是', '等离子', '的']
# ['对面', '就', '是', '栈桥']
# ['相当', '舒适']
# ['非常', '好']
# ['字']
# ['烂']
# ['这', '家', '在', '3', '年', '前', '还', '是', '无锡', '市区', '比较', '好']
# ['有', '档次', '有', '服务', '的', '酒店']
# ['不', '知', '都', '吃', '了', '什', '药']
# ['的', '都', '变', '了']
# ['酒店', '对', '预定', '的', '客人', '有', '偏见']
# ['总是', '故意', '安排', '一些', '差', '的']
# ['将', '好', '的', '设施', '和', '床', '都', '搬', '到', '高层', '去', '作为', '了']
# ['整体', '感觉']
# ['的', '与', '实际', '得到', '的', '水平', '不', '符']
# ['床', '都', '是', '老', '旧', '的']
# ['更', '气愤', '的', '是']
# ['总是', '忽冷忽热']
# ['水流', '不', '畅']
# ['保龄球馆', '的', '服务', '还', '不', '错']
# ['补充', '点评', '2006年', '8月', '：', '下面', '的', '位', 'XDJM', '估计', '没', '怎', '住', '过', '酒店']
# ['所有', '的', '酒店', '都', '应该', '可以', '用', '信用卡', '押金', '和', '的', '啊']
# ['对', '了']
# ['酒店', '40', '元', '天', '的', '真是', '抢', '钱', '啦']
# ['这种', '行为', '比', '之', '红色', '产业', '还', '职业道德']
# ['酒店', '将', '的', '佣金', '全部', '转嫁', '到', '旅客', '身上', '了']
# ['早餐', '要', '50', '大洋']
# ['的', '448', '的']
# ['我', '可以', '在', '店面', '得到', '438', '含', '早', '和', '宽带']
# ['补充', '点评', '2006年', '8月', '：', '睡', '大街', '不', '住', '这', '家', '锦江', '了']
# ['典型', '的', '北京', '人', '经营', '的', '国营', '的']
# ['态度', '生硬']
# ['冷冰冰']
# ['我', '不', '带', '多少']
# ['他们', '却', '拒绝', '使用']
# ['中行', '之外', '的', '信用卡']
# ['还', '说', '我', '难', '为', '了']
# ['那', '外国人', '谁', '有', '这', '两', '种', '?', '我', '是', '不', '会', '再', '去', '受', '这', '窝', '了']
# ['劝', '您', '别', '去', '这', '的', '破', '北京', '人', '旅馆']
# ['住', '过', '温馨', '大', '和']
# ['窗', '是', '最', '头疼', '的', '问题']
# ['较', '潮湿']
# ['第二', '天', '胳膊', '上', '起', '了', '红色', '的', '点点']
# ['比较', '郁闷']
# ['服务', '倒是', '不', '错']
# ['由于', '洗手间', '的', '换气扇', '不', '灵']
# ['服务员', '很快', '就', '给', '修理', '好', '了']
# ['价', '位', '还', '可以']
# ['但是', '性', '价', '比', '就', '不', '行', '了']
# ['有', '机会', '住', '下', '有', '窗', '的', '应该', '会', '好', '很多']
# ['不', '小']
# ['干净']
# ['设施', '很', '新']
# ['服务', '很', '好']
# ['性', '价', '比', '很', '高']
# ['感觉', '不', '错']
# ['很']
# ['价', '格', '合适']
# ['这个', '价', '位', '住', '五星级', '酒店', '还是', '很', '划算', '的']
# ['上网', '和', '游泳', '都', '是', '免费']
# ['游泳', '水', '有']
# ['估计', '不', '到', '28', '度']
# ['电视', '节目', '不', '少']
# ['的', '床', '很', '大']
# ['早餐', '种类', '多']
# ['美味']
# ['但是', '饭店', '和', '超市']
# ['想', '吃', '零食', '只好', '了']
# ['感觉', '很', '好']
# ['性', '价', '比', '不', '错']
# ['唯一', '的', '缺点', '就', '是', '放', '行李', '的', '地方']
# ['桌子', '上', '的', '书', '占', '地方']
# ['南侧', '的', '紧邻']
# ['且', '窗户', '隔音', '不', '是', '很', '好']
# ['有些', '吵']
# ['北侧', '的', '还', '可以', '吧', '到', '是', '干净']
# ['就', '是', '陈设', '略', '显', '陈旧']
# ['价', '格', '在', '同等', '宾馆', '来', '说', '偏', '高']
# ['环境', '不', '错']
# ['服务', '很', '到位']
# ['很', '好']
# ['早饭', '可以', '再', '做', '改进']
# ['宽敞', '明亮']
# ['家', '简直', '比', '四', '星', '的', '还', '要', '好']
# ['很', '干净']
# ['态度', '非常', '好']
# ['本人', '住', '了', '1400', '个', '五星级', '酒店', '晚上']
# ['这', '间', '是', '从', '来', '最', '差']
# ['热水', '不', '热']
# ['设备', '烂']
# ['门锁', '开', '不', '到']
# ['要', '什麽', '都', '是', '烂']
# ['我', '住', '了', '五', '晚', '呢']
# ['唉']
# ['最', '衰', '的', '五星级', '酒店']
# ['地段', '不', '错']
# ['对面', '就', '是', '武林', '广场']
# ['很', '宽敞', '、', '干净']
# ['前台', '蛮', '好']
# ['主动', '介绍', '了', '其他', '更', '适合', '的']
# ['各', '都', '非常', '到位']
# ['达到', '了', '国际', '五星级', '酒店', '标准']
# ['酒店', '很', '洁净']
# ['空间', '布局', '很', '合适']
# ['让', '人', '感觉', '很', '；', '设施', '齐全']
# ['功能', '完善']
# ['所有', '的', '东西', '都', '如', '崭新', '的', '般', '；', '餐厅', '跟', '欧洲', '一样']
# ['摆设', '还', '是', '品种']
# ['都', '是', '一流', '的', '；', '24', '小时', '服务', '很', '到位']
# ['晚上', '11点', '入住']
# ['还', '可以', '要求', '洗衣', '服务']
# ['次日', '晨', '早餐', '时间', '回']
# ['真', '的', '很', '体贴']
# ['入住', '该', '酒店', '真正', '让', '人', '感觉', '到', '宾至如归']
# ['酒店', '价', '格', '很', '合理']
# ['适合', '人士', '入住']
# ['很', '好']
# ['很', '安静']
# ['环境', '好']
# ['给', '客人', '留下', '了', '很', '好', '的', '印象']
# ['再', '不', '会', '住', '此', '酒店']
# ['前台', '对', '酒店', '周围', '情况', '无', '了', '解']
# ['到', '酒店', '时', '是', '晚上', '六点']
# ['要', '急', '去', '浦东', '机场', '接', '客人']
# ['问', '前台', '磁悬浮', '到', '几']
# ['只', '到']
# ['结果', '打车', '一百', '多', '到', '机场']
# ['发现', '磁悬浮', '到', '九点']
# ['后', '来', '又', '问', '到', '展馆', '多少', '公里']
# ['大约', '三', '公里']
# ['实际', '走', '有', '将近', '七', '公里']
# ['酒店', '早餐']
# ['只好', '喝', '牛奶']
# ['酒店', '十二点', '以后', '还有', '骚扰', '电话']
# ['只好', '拔', '电话']
# ['入住', '、', '巨', '慢']
# ['酒店', '周围', '一点五', '公里', '无', '超市']
# ['酒店', '晚上', '惟有', '酒', '吧']
# ['客人', '晚上', '在', '酒', '吧', '要', '了', '瓶', '啤酒']
# ['竟', '收费', '一百', '元']
# ['干净', '整洁']
# ['前台', 'check', 'i', 'n', 'out', '迅速']
# ['不', '错', '的', '酒店']
# ['环境', '好']
# ['设施', '好']
# ['服务', '好']
# ['开车', '方便']
# ['远离', '市区']
# ['度假村']
# ['不', '会', '再', '选择', '这里', '入住']
# ['奉劝', '大', '家', '小心', '被', '敲诈']
# ['尤其', '是', '单身', '女性']
# ['算是', '很', '不', '错']
# ['就', '是', '酒店', '的', '价格', '起伏', '太', '大']
# ['服务', '还', '算', '可以']
# ['我', '对', '这个', '酒店', '一直', '都', '很', '满意']
# ['今后', '还', '将', '继续', '支持', '这个', '酒店']
# ['单', '人间', '面积', '较', '小']
# ['不', '过', '标准', '间', '非常', '不', '错', '有', '30', '多', '个', '平方']
# ['豪华', '还有', '会客', '的', '沙发', '布局', '非常', '的', '合理']
# ['设计', '装修', '很', '有', '格调']
# ['住', '的', '非常']
# ['服务', '很', '好']
# ['值班', '经理', '、', '前台', '接待', '还是']
# ['都', '非常', '有', '效率']
# ['态度', '很', '好']
# ['楼层', '服务员', '特别', '的']
# ['特别', '需要', '提', '的', '是']
# ['我', '带', '团队', '入住']
# ['由于', '走', '的', '时间', '很', '早']
# ['为', '了', '不', '耽误', '客人', '旅游', '的', '时间']
# ['本', '打算', '给', '客人', '准备', '路', '早']
# ['可是', '既然', '餐厅', '就', '同意', '给', '客人', '提前', '单独']
# ['如此', '为', '客人', '着想']
# ['我', '还', '是', '第一', '次', '见到']
# ['非常', '感动']
# ['以后', '只要', '到', '成都', '还', '住', '大酒店']
# ['我', '再', '不', '会', '住', '在', '这个', '长航', '大酒店', '了']
# ['我', '是', '19日', '深夜', '到', '武汉']
# ['在', '出租车', '上面', '通过', '电话', '订', '的']
# ['要求', '他们', '看', '网友', '评论', '怎样']
# ['不', '愿意', '说']
# ['我', '只好', '勉强', '接受']
# ['住', '晚']
# ['靠']
# ['真是', '靠']
# ['以后', '我', '打', '死', '不', '住', '了']
# ['床', '铺', '我', '没', '敢', '仔细', '看', '就', '睡', '了']
# ['那个', '洗手间', '的', '马桶', '啊']
# ['马', '桶', '垫', '黄', '黄', '的', '圈']
# ['旁边', '放', '着', '待', '出售', '的', '安全', '套']
# ['当天', '小姐', '跟', '我', '说', '空调', '坏', '了']
# ['要', '知道']
# ['武汉', '的', '温度', '当时', '真是', '闷热']
# ['我', '去', '开', '窗']
# ['结果', '吵', '死', '了']
# ['楼下', '车水马龙']
# ['还有']
# ['武汉', '车', '是', '不', '是', '都', '喜欢', '按', '喇叭']
# ['我', '实在', '睡', '不', '着']
# ['只好', '关', '窗']
# ['靠']
# ['那', '窗', '就', '的']
# ['关上', '以后', '的', '声音', '关', '一样']
# ['郁闷', '啊']
# ['像', '我', '这种', '楼上', '装修', '还', '能', '我', '自', '坦然', '睡觉', '的', '人']
# ['早上', '很', '早', '硬是', '被', '这', '破', '窗户', '外面', '的', '片', '车', '喇叭', '吵', '醒', '了']
# ['现在', '很', '少', '有', '不', '免费', '提供', '宽带', '的', '酒店', '啊']
# ['知道', '吗']
# ['长航', '大酒店', '居然', '要', '20', '块', '天']
# ['我', '19日', '深夜', '要求', '开通']
# ['结果', '是', '20日', '凌晨', '1点', '多', '开通', '了', '上网', '用', '了', '半', '小时']
# ['结果', '睡', '了', '觉', '起', '来', '就', '不', '能', '用', '了']
# ['还有', '事', '要', '给', '大', '家', '分享', '一下']
# ['有', '天', '早晨', '我', '从', '出', '来']
# ['非常', '安静']
# ['我', '开门', '后', '一直', '朝', '左', '看', '的']
# ['突然', '在', '我', '背后', '不', '到', '30', 'CM', '的', '地方', '冒', '出', '句', '：', '你好']
# ['天']
# ['把', '我', '给', '吓', '的']
# ['直接', '蹲', '到', '了', '地上']
# ['象', '幽灵', '般']
# ['吓', '死', '我', '了']
# ['鉴于', '常住', '酒店', '的', '原故']
# ['觉得', '自己', '有', '必要', '过', '的', '真实', '说', '出', '来', '给', '大', '家', '分享', '一下']
# ['24', 'K', '的', '名字', '听', '起', '来', '不错']
# ['有', '国际', '的', '感觉']
# ['在', '网上', '的', '时候', '看到', '紧张', '状态']
# ['我', '以为', '只有', '好', '的', '酒店', '才', '会', '出现', '紧张']
# ['但', '实际', '情况', '是', '：', '1']
# ['酒店', '的', '位置', '很', '难', '找']
# ['躲', '在', '偏僻', '的']
# ['出门', '是', '垃圾堆']
# ['恶臭']
# ['真', '的', '佩服', '拍', '图片', '的', '人']
# ['在', '网上', '门面', '看', '起', '来', '挺', '不', '错', '的']
# ['2']
# ['楼道', '的', '地毯', '不', '知道', '多久', '清洗', '了']
# ['很', '脏']
# ['我', '入', '住', '的', '时候', '正在', '打扫', '卫生']
# ['于是', '我', '对', '那', '个', '阿', '姨', '说', '：', '能', '请', '您', '帮', '我', '吸', '一下', '地毯', '吗']
# ['你', '猜', '她', '怎', '说', '：', '她', '说', '地毯', '本', '来', '就', '是', '这样', '的']
# ['吸', '了', '一样']
# ['晕倒']
# ['但', '我', '还', '是', '坚持', '要', '她', '象征性', '的', '吸', '了', '一下']
# ['心里', '一点']
# ['3']
# ['楼道', '之间', '有', '异味']
# ['许', '是', '正在', '装修', '的', '原因']
# ['4']
# ['设计', '十分', '可笑']
# ['进', '门', '还有', '通道']
# ['却', '十分', '窒息']
# ['只', '有', '床']
# ['电视柜', '和', '床', '挨', '在', '一起', '了']
# ['5']
# ['是', '地毯']
# ['可是', '通道', '和', '卫生间', '却']
# ['结果', '我', '洗澡', '出', '来']
# ['脚', '踩', '上去', '摔', '了', '个', '半死']
# ['太', '滑', '了']
# ['没', '去', '投诉']
# ['知道', '这', '用']
# ['只是', '说', '出', '来']
# ['让', '后', '去', '的', '人', '提', '个', '醒']
# []
# ['一切', '的', '一切']
# ['有', '胆量', '的', '人才', '可以', '去', '那里', '住']
# ['床', '超大']
# ['横', '着', '竖', '着', '都', '能', '睡']
# ['卫生间', '面积', '虽然', '不', '大']
# ['但是', '布局', '很', '合理']
# ['所以', '洗浴', '的', '空间', '非常', '大']
# ['不', '错', '啦']
# ['离', 'YOU', '近']
# ['呵呵']
# ['曙光', '路', '还是', '不', '错', '的', ':', 'P']
# ['服务', '周到']
# ['环境', '温馨']
# ['干净', '卫生']
# ['底', '楼', '的', '日本', '地道', '正宗']
# ['但', '酒店', '稍', '显', '陈旧']
# ['所谓', '仅', '能', '从', '窗户', '的', '一角', '看到', '海景']
# ['不', '能', '正面', '直视']
# ['2006年', '1月', '７日', '入', '住']
# ['感觉', '窗户', '漏风']
# ['旧']
# ['卫生间', '很', '小']
# ['早餐', '不', '好']
# ['网上', '说', '有', '四', '个', '餐厅']
# ['其实', '只', '有']
# ['而且', '餐厅', '太', '差']
# ['而且', '价', '格', '贵']
# ['总体', '评', '价', '冲', '其', '量', '星', '吃饭', '要', '走', '好', '远']
# ['还要', '穿过', '阴冷', '的', '走廊', '元', '的', '早餐', '我', '在', '外面', '吃', '只', '要', '花', '五', '元', '吃', '得', '比', '它', '好']
# ['它', '有', '两', '部', '电梯']
# ['说', '部', '给', '房客', '用', '部', '施工', '用']
# ['如果', '你', '进', '了', '施工', '的', '那', '部', '你', '会', '觉得', '进', '了', '工地', '的', '施工', '现场']
# ['本', '来', '想', '住', '两', '晚']
# ['只', '住', '了', '晚']
# ['自己', '前面', '住', '的', '附近', '三星', '酒店', '价', '格', '比', '它', '便宜']
# ['但', '感觉', '要', '比', '它', '好', '得', '多']
# ['个人', '认为', '不', '错']
# ['入住', '时', '能', '尽量', '满足', '客人', '要求']
# ['环境', '不', '错']
# ['离', '时代', '广场', '又', '近']
# ['好']
# ['觉得', '非常', '好']
# ['很', '国际化']
# ['这次', '去', '了', '三', '个', '城市']
# ['这个', '酒店', '给', '我', '感觉', '最好']
# ['而且', '服务', '态度', '很', '好']
# ['推荐']
# ['总体', '影响', '还', '可以']
# ['就', '是', '办公', '不', '太', '方便']
# ['底层', '大堂', '两', '台', '电脑', '有点', '太', '破旧', '了']
# ['上网', '都', '不', '太']
# ['能', '否', '考虑', '换', '掉']
# ['或者', '搞', '个']
# ['让', '客人', '会', '方便', '些']
# ['入住', '期间']
# ['位', '姓', '刘', '的', '客房', '服务员', '从', '我', '的', '生活', '特征', '中', '知道', '了', '我', '吃', '药', '、', '喝茶', '的', '习惯', '后', '主动', '提供', '热水瓶', '和', '茶叶']
# ['后', '又', '将', '我', '忘', '在', '鞋', '的', '袜子', '洗', '干净', '晾晒']
# ['如此', '种种', '让', '我', '有', '了', '回到', '家', '的', '感觉']
# ['下次', '到', '宜昌', '还', '住', '半岛']
# ['不', '过', '确实', '有']
# ['还', '有', '希望', '能', '给', '更', '好', '的', '价格']
# ['我们', '定', '的', '是', '178', '的']
# ['但', '只', '比', '门市', '价', '少', '20', '元']
# ['还', '早餐']
# ['我', '在', '北京', '住', '过', '很多', '的', '酒店', '和', '公寓']
# ['以下', '是', '对于', '华威', '的', '评', '价', '：', '1']
# ['我', '要求', '入', '住', '间', '豪华']
# ['希望', '有', '浴缸']
# ['靠近', '二环路']
# ['都', '及时', '准确', '地', '给', '予', '了', '预定']
# ['2']
# ['的', '格局', '以及']
# ['都', '十分', '的', '豪华']
# ['家', '具', '很', '考究']
# ['装修', '很', '有', '品位']
# ['3']
# ['有', '浴缸', '和']
# ['双重', '的', '享受']
# ['很', '满意']
# ['4']
# ['用品', '很', '精致']
# ['特别', '是', '华威', '独有', '的', '的', '小', '香皂']
# ['5']
# ['冰箱', '有', '免费', '的', '矿泉水']
# ['还有', '免费', '的', '咖啡']
# ['很', '照顾', '客人', '的', '需求']
# ['6']
# ['张', '大', '床', '可以', '睡', '下', '4', '个', '人', '的', '那种']
# ['很', '惬意']
# ['7']
# ['落地', '窗户', '和', '欧式', '的', '窗帘']
# ['晚上', '站', '在', '看', '环', '的', '夜景', '很', '不', '错']
# []
# ['有些', '客人', '觉得', '地理', '位置', '不', '方便']
# ['因为', '整体', '感觉', '不', '错']
# ['所以', '不', '会', '很', '在意']
# ['9']
# ['早餐', '是', '最', '令', '我', '意外', '的']
# ['是', '我', '吃', '过', '最', '豪华', '的', '英式', '早茶']
# ['强烈', '推荐', '的']
# ['10']
# ['唯一', '的', '不足', '可能', '就', '是', '楼道', '总', '有', '一些', '异味']
# ['总', '的', '来说']
# ['在', '北京', '我', '住', '过', '很多', '公寓']
# ['这', '是', '唯一', '间', '让', '我', '不', '想', '离开', '的', '旅途', '转折点']
# ['浴室', '污秽', '不', '堪']
# ['无']
# ['洗', '完', '到处', '都', '湿漉漉']
# ['无', '挂钩']
# ['衣物', '毛巾', '都', '不', '知', '放', '那里']
# ['无']
# ['肥皂', '要', '拿', '在', '手上', '冲凉']
# ['原本', '住', '三', '天']
# ['翌日', '即', '走']
# ['比较', '小']
# ['比较', '简陋']
# ['连', '像样', '的', '坐', '的', '地方', '都']
# ['还有', '最', '重要', '的', '是', '入', '住', '的', '千万', '不', '要', '靠', '钱', '王', '大街']
# ['太', '吵']
# ['补充', '点评', '2006年', '10月', '6日', '：', '还有', '是', '表面', '干净']
# ['其实', '很', '恐怖']
# ['凌晨', '被', '大街', '上', '的', '车', '吵']
# ['居然', '闻', '到', '了', '被子', '的', '怪味']
# ['垃圾', '宾馆']
# ['很', '脏']
# ['连', '基本', '的', '洗发', '水', '和', '沐', '浴', '露']
# ['空调', '小', '的', '几乎']
# ['蚊子']
# ['夜', '没', '睡', '好']
# ['血', '的', '代', '价']
# ['要', '不', '是', '在', '客户', '隔', '壁', '偷', '了']
# ['和', '的', '没法', '比']
# ['差', '70', '块']
# ['差', '太', '多', '了', '吧']
# ['最', '多', '达到', '2', '星', '水准']
# ['下次', '看看', '它', '隔', '壁', '的', '家', '新', '的', '酒店', '怎', '样']
# ['反正', '再', '不', '去', '了']
# ['对', '了', '门口', '没', '侍应生', '我', '是', '拖', '着', '好多', '东西', '跌跌撞撞', '得', '进去', '得']
# ['酒店', '是', '很', '不', '错']
# ['设施', '很', '好']
# ['的', '价格', '能', '再', '低', '就', '更', '好', '了']
# ['perfect']
# ['room', 'i', 's', 'big', 'clean']
# ['酒店', '的', '服务', '非常', '好']
# ['入住', '和', '退', '房', '速度', '很快']
# ['非常', '干净', '很', '漂亮']
# ['下次', '去', '一定', '再', '住']
# ['保安', '服务', '不', '太', '满意']
# ['主要', '是', '停车', '安排', '问题', '解决', '不', '了']
# ['1']
# ['地点', '位于', '市中心']
# ['机场', '出', '来', '乘', '67', '路', '到', '“', '交', '三', '桥', '”', '站', '下']
# ['步行', '5', '分钟', '即', '可', '到', '酒店']
# ['2']
# ['很', '干净']
# ['很', '大']
# ['住', '得', '很']
# ['3']
# ['酒店', '服务', '非常', '好']
# ['到', '昆明', '住', '金泉', '不', '错']
# ['2', '－', '3日', '入住']
# ['说', '是', '免费', '给', '我', '升', '为']
# ['结果', '是', '新', '装修', '的']
# ['甲醛', '无比']
# ['卫生间', '有', '恶臭']
# ['设施', '不好']
# ['还', '普通', '间', '好']
# ['自', '住', '早餐', '环境', '和', '质量', '比较', '差']
# ['因为', '入', '住', '比较', '晚', '了']
# ['不', '方便', '联系', '其他', '酒店']
# ['只好', '住', '了', '天']
# ['逃']
# ['环境', '不', '错']
# ['很', '安静']
# ['设施', '很', '新']
# ['很', '干净']
# ['服务', '不错']
# ['就是', '前台', '办理', '速度', '有待', '提高']
# ['如果', '通过', '能', '拿', '到', '更', '好', '的', '就', '好', '了']
# ['住', '了', '晚上']
# ['这次', '住', '的', '时候', '和', '他们', '说', '会员卡', '丢', '了']
# ['没', '上班', '不', '给', '积分', '了']
# ['我', '很', '生气']
# ['走', '的', '时候']
# ['我', '下次', '肯定', '不', '住', '了']
# ['暖气', '不', '够', '不', '喜欢']
# ['1', '、', '抵达', '：', '开车', '抵达', '酒店']
# ['询问', '如何', '停车']
# ['远远地', '站', '着']
# ['根本', '不', '搭', '利', '你']
# ['2', '、', '停车', '：', '被告', '之', '要', '收', '停车费']
# ['然后', '拿', '着', '对讲机', '把', '你', '的', '车上', '看', '起', '来', '有', '的', '地方', '通报']
# ['我', '问', '：', '“', '您', '报', '我', '的', '车', '有', '伤']
# ['你们', '登记', '确认', '的', '内容', '我', '本人', '确认', '了', '吗']
# ['”']
# ['曰', '：', '“', '一律', '以', '我们', '的', '汇报', '为', '准']
# ['”', '我', '大', '笑']
# ['说', '：', '“', '那', '给', '你们', '提', '个', '建议', '：', '‘', '以后', '一律', '报', '遍体鳞伤']
# ['外观', '全部', '损坏', '’']
# ['又', '省事']
# ['又', '不', '任何']
# ['”', '3', '、', '登记', '：', '整个', '前台', '接待', '只', '有', '人']
# ['来', '接待', '50', '人', '以上', '的', '入住', '登记', '（', '有', '旅行团', '）']
# ['牛', '吧']
# ['通', '激烈', '的', '争吵', '投诉', '后']
# ['被告', '之', '：', '查', '到', '预定', '信息']
# ['我', '倒']
# ['赶忙', '再', '找', '确认']
# ['最后', '才', '发现', '是', '酒店', '把', '我', '预定', '的', '名字', '给', '写', '错', '了']
# ['（', '但', '我', '深表', '怀疑']
# ['估计', '是', '对', '前面', '激烈', '争吵', '的', '报复']
# ['）', '4', '、', '就餐', '：', '13', '：', '40', '抵达']
# ['杯']
# ['只', '有', '2', '个', '服务员', '在', '打扫']
# ['看', '客人', '进', '来']
# ['无人问津']
# ['我', '一阵', '狂', '吼']
# ['很', '不', '情愿', '地', '过', '来', '告诉', '我', '：', '14', '：', '00点', '下班']
# []
# ['你们', '别', '在', '这里', '吃', '了']
# ['我', '陡', '起']
# ['我', '就', '还', '非', '在', '你', '这里', '吃', '呢']
# ['我', '又', '错', '了']
# ['要', '了', '锅贴', '（', '类似', '煎', '饺子', '的', '食品', '）']
# ['45', '分钟', '过去', '你', '上']
# ['5', '、', '早餐', '：', '怎', '就', '“', '差', '”', '字', '了', '得']
# ['更为', '搞笑', '的', '是', '：', '居然', '有', '三', '个', '人', '站', '在', '前面', '“', '”', '“', '名', '家', '”', '字画']
# ['6', '、', '：', '问', '都', '不', '问', '直接', '就要', '刷', '我', '的']
# ['自己', '急忙', '阻止']
# ['要求', '看', '帐单']
# ['帐单', '显示', '查', '房', '说']
# ['消费', '了', '2', '个']
# ['我', '马上', '打电话', '找', '太太', '核实']
# ['确认', '消费']
# ['要求', '再次', '查房']
# ['结果', '回报', '：', '确实', '消费']
# ['消费', '发生']
# ['可', '我', '和', '太太', '的', '长途', '+', '漫游', '的', '确实', '发生', '了']
# ['忠告', '：', '凡', '入', '住', '本']
# ['一切', '消费', '以', '酒店', '为准']
# ['不', '要', '地', '去', '核实']
# ['以免', '再', '发生', '高额', '的', '长途', '+', '漫游', '的']
# ['7', '、', '提示', '：', '在', '本', '酒店', '刷', '消费']
# ['不', '接受', '“', '”', '标志', '的']
# ['一律', '额外', '要', '收', '手续费']
# ['建议', '多', '带', '哦']
# ['这', '家', '酒店', '是', '黑', '店']
# ['入住', '时', '是', '条', '浴巾']
# ['结账', '时', '说', '两', '条']
# ['因', '要', '上', '飞机']
# ['时间', '同', '她们', '理论']
# ['陪', '了', '80', '元']
# ['急急', '的', '走', '了']
# ['后', '来', '觉得', '这', '家', '店', '是', '有意', '这样', '坑害', '顾客', '的']
# ['明明', '是', '条']
# ['是', '两', '条']
# ['以后', '入', '住', '的', '客人', '一定', '留心']
# ['发现', '不', '对']
# ['尽快', '同', '店', '家', '说明']
# ['否则', '结账', '时', '说', '不', '清']
# ['可能', '早', '说', '用']
# ['她们', '是', '有意', '这样', '做', '的']
# ['建议', '以后', '都', '不', '要', '去', '住']
# ['给', '老板', '定', '的', '酒店']
# ['住', '了', '十', '来', '天']
# ['回', '来', '说', '还', '不', '错']
# ['主要', '的', '环境', '很', '好']
# ['吃喝玩乐', '很', '方便']
# ['就', '是', '不', '早餐', '有些', '郁闷']
# ['大堂', '就', '有', '股', '轻微', '的']
# ['好像', '进入', '地下室', '的', '气味']
# ['里', '更', '重']
# ['睡觉']
# ['我', '只能', '下午', '就', '退', '房']
# ['但', '酒店', '还是', '收', '了', '我', '天', '的', '房钱']
# ['永远', '不', '再', '来', '这', '家', '酒店']
# ['1']
# ['预定', '确认', '了']
# ['但是', '到', '了', '杭州', '后', '来', '能', '不', '能', '帮', '我', '酒店']
# ['原', '来', '的', '满', '了']
# ['还', '好', '我们', '已经', '入', '住', '了']
# ['克斯', '很', '是', '纳闷']
# ['以前', '碰到', '过', '这', '差', '的', '服务', '啊']
# ['哪', '有', '已经', '确认', '的', '事情', '还', '有', '变', '的', '啊']
# ['2']
# ['黄龙', '确实', '老', '了']
# ['下水道', '不', '好']
# ['餐厅', '服务', '差', '（', '预定', '好', '的', '居然', '记录']
# ['被迫', '换']
# ['还', '好', '有']
# ['否则', '客户', '面前', '如何', '交代', '）']
# ['慢']
# ['1', '天', '的', '上网', '费用', '计算', '成', '2', '天', '的']
# ['咳']
# ['一切', '都', '不', '是', '15', '年', '前', '的', '感觉', '了', '（', '以前', '经常', '带', '团', '到', '这里', '呢', '）']
# ['唯一', '不', '变', '的', '是', '服务', '生', '要', '小', '费', '的', '眼神', '和', '期盼']
# ['别墅区', '环境', '非常', '好']
# ['太', '漂亮', '了']
# ['本人', '住', '20', '号']
# ['卫生间', '非常', '大']
# ['感觉', '不', '错']
# ['院落', '本身', '很', 'PP']
# ['不', '足', '：', '每天', '赠送', '的', '水果', '般']
# ['香蕉', '都', '是', '的']
# ['入', '住', '第2', '天', '拿', '来', '个', '加湿器', '（', '空气', '很', '干', '）']
# ['第3', '天', '才', '有', '赠送', '的', '牛奶']
# ['早餐', '品种', '般']
# ['服务', '不', '错']
# ['很', '热情']
# ['就', '是', '房', '价', '相比', '其他', '4', '星', '稍微', '贵', '了']
# ['小']
# ['卫生间', '看上去', '脏']
# ['前台', '押金', '要', '付']
# ['不', '方便']
# ['下次', '不', '去']
# ['如', '家', '一直', '不', '错', '的']
# ['干净', '整洁']
# ['服务', '快速', '热情']
# ['不', '错']
# ['非常', '不', '错', '的', '酒店']
# ['服务', '态度', '和', '环境', '都', '很', '不', '错']
# ['就是', '价', '格', '还', '有些', '偏', '高']
# ['而且', '不', '该', '外宾']
# ['春节', '住', '的', '地方']
# ['太', '了']
# ['真是', '让', '人', '回味', '啊']
# []
# ['上网', '痛快']
# ['给', '我', '的', '感觉', '就', '是', '2', '个', '字']
# []
# ['还是']
# ['希望', '下次', '去', '的', '时候', '还', '是', '自己', '住', '那里']
# ['呵呵']
# ['唯一', '不', '好', '的', '就', '是', '吃', '的', '东西']
# ['全部', '是', '西餐']
# ['中国', '人', '怎', '可以', '这样', '呢', '?', '哎']
# ['真是', '啊']
# ['出去', '吃', '的', '话', '要', '走', '路', '呢']
# ['不', '过去', '机场']
# ['13', '钱', '就', '到', '了']
# ['不', '会', '那', '赶', '时间']
# ['呵呵']
# ['建议', '以后', '大', '家', '去', '住']
# ['服务', '太', '差', '了']
# ['离', '店', '时', '不', '开', '发票']
# ['等', '老子', '要', '报账', '时', '才', '发现']
# ['和', '前台', '的', '讲明', '情况', '后']
# ['居然', '要', '我', '等', '2', '个', '小时', '后', '再', '打电话']
# ['什', '态度']
# []
# ['我', '看', '了', '前面', '网友', '的', '评', '价', '才', '住', '了', '这', '家', '酒店']
# ['什', '破', '阿']
# ['设施', '好像', '是', '80', '年代', '的']
# ['整个', '阴暗', '潮湿']
# ['墙上', '还有', '发霉', '的', '痕迹']
# ['卫生间', '眼', '看上去', '就', '不', '清爽']
# ['龙头', '出', '来', '的', '水', '好像', '老太婆', '撒尿', '一样']
# ['窗户', '打', '不', '开']
# ['床板', '很', '硬']
# ['不', '能', '上网']
# ['还要', '190']
# ['我', '退', '房', '的', '时候', '有', '协议', '的', '客户', '才', '付', '了', '的', '房费']
# ['吐血']
# ['千万', '不', '要', '去']
# ['网上', '的', '照片', '和', '实际', '的', '相差', '很', '大']
# ['虽然', '在', '市中心']
# ['但是', '走', '到', '还是', '有', '很多', '路']
# ['而且', '不', '是', '中山路', '边上', '的']
# ['凹', '进去', '一点', '的', '地方']
# ['空气', '清新']
# ['满眼', '绿色']
# ['这', '就', '是', '我', '来', '这', '家', '宾馆', '的', '印象']
# ['刚', '来', '时']
# ['搞', '不', '清楚', '他们', '分', '的', '几', '号', '楼', '几', '号', '楼']
# ['所以', '逮', '到', '路过', '的', '宾馆', '员工', '就', '是', '上去', '问']
# ['但', '他们', '都', '不厌其烦', '的', '给', '我', '指', '路']
# ['服务', '很', '周到', '、', '温馨']
# ['另外']
# ['我', '特别', '喜欢', '这边', '餐厅', '的', '道', '菜', '--', '“', '排', '骨', '”']
# ['上', '上', '的', '芝麻']
# ['吃', '起', '来', '不', '是', '想象', '的', '辣']
# ['而是', '香']
# ['感觉', '很', '好']
# ['处处', '都', '能', '感觉', '到', '是']
# ['只', '是', '我', '住', '的', '墙壁', '上', '有', '已']
# ['感觉', '有点', '的']
# ['呵呵', '有', '机会', '还是', '会', '去', '住', '住', '的']
# ['该', '酒店', '极', '差']
# ['服务', '设施', '及', '其一', '般']
# ['需要', '外出', '寻找', '早餐']
# ['大堂', '很', '漂亮', '餐厅', '很', '不', '错', '宽', '带', '上网', '收费', '每', '12', '小时', '50', '元', '24', '小时', '100', '元']
# ['前天', '入住']
# ['昨天', '退', '房']
# ['感觉', '真', '的', '是', '很', '好']
# ['服务', '热情']
# ['好']
# ['我', '去', '的', '时候', '比', '预定', '到', '店', '的', '时间', '早', '了', '3', '个', '小时']
# ['前台', '说', '没', '问题']
# ['拿', '起', '对讲机', '：', '“']
# ['加急', '处理']
# ['”', '我', '上楼']
# ['好', '家', '伙']
# ['几', '个', '服务员', '一起', '收拾']
# ['那', '叫', '快速']
# ['问问', '如果', '不', '是', '加急', '需要', '多', '长', '时间']
# ['回答', '是', '：', '“', '50', '分钟', '左右']
# ['”', '后', '来', '我', '看', '表']
# ['15', '分钟']
# []
# ['确实', '是']
# ['住', '起', '来', '是', '很', '爽']
# []
# ['（', '我', '女', '朋友', '脚', '还', '真', '把', '我', '踹', '不', '下去', '呀']
# ['真是', '感慨']
# ['太', '好', '了']
# ['哈哈', '）', '后', '来', '觉', '到', '天亮']
# ['爽', '呀']
# ['我', '女', '朋友', '都', '不', '想', '走', '了']
# ['但是', '没', '办法', '呀']
# ['还是', '要', '回', '来', '上班']
# ['大厅', '满', '气派', '的']
# ['副', '楼', '就', '旅馆', '的', '水平', '吧']
# ['电视机', '是', '80', '年代', '的', '产物']
# ['频道', '很', '少']
# ['窗外', '就是', '平台']
# ['乱七八糟', '的']
# ['根本', '不', '敢', '开', '窗']
# ['床', '很', '短']
# ['卫生间', '看', '了', '就', '不', '敢', '用']
# ['旧', '、', '脏']
# ['我', '是', '外出', '洗', '得', '澡']
# ['感觉', '和', '价', '格', '严重', '不', '符']
# ['算是', '不', '错', '的']
# ['至少', '地段', '出入', '很', '方便']
# ['尽管', '住', '的', '是', '四百', '多', '无', '窗', '的', '床']
# ['感觉', '有点', '压抑']
# ['可是', '出', '来', '玩', '的', '话']
# ['其实', '一整天', '在', '外面', '的']
# ['只', '在', '晚上', '睡觉', '时', '才', '会', '在', '的', '啦']
# ['实在', '是', '差']
# ['简直', '象', '个', '招待所']
# ['劝告', '其他', '朋友']
# ['千万', '别', '住']
# ['别', '说', '我', '告诉', '过', '你']
# ['另外']
# ['外面', '有', '许多', '的']
# ['做', '为', '的', '忠实', '客户']
# ['我', '觉得', '有']
# ['有', '义务', '客观', '公正', '的', '就', '该', '酒店', '存在', '的', '问题']
# ['进行', '揭露']
# ['9月', '1日', '晚', '7点', '男友', '入', '住', '通过', '的', '大', 'A', '（', '228', '元', '）']
# ['10', '左右', '我', '抵达']
# ['进', '301', '号', '房']
# ['我', '就', '觉得', '与', '上次', '不', '同']
# ['和', '床', '都', '小', '了', '很多']
# ['因', '男友', '已', '入睡']
# ['想', '次日', '再', '与', '宾馆', '交涉']
# ['结果', '两', '人', '夜', '无眠']
# ['隔壁', '的']
# ['关门', '声']
# ['电话', '铃声']
# ['以及', '窗外', '的', '车', '来', '车', '往']
# ['声声', '入', '耳']
# ['9月', '2日']
# ['男友', '与', '交涉']
# ['谴责', '宾馆', '把', '188', '元', '的', '大', '蒙骗', '顾客', '冒充', '228', '元', '的', '大', '卖']
# ['随后', '我们', '换', '至', '501', '房']
# ['大', '了', '一些']
# ['床', '明显', '大', '了', '许多']
# ['是', '2', '米', '的']
# ['9月', '3日']
# ['中午', '11点']
# ['我', '独自', '到', '办理', '退', '房', '手续']
# ['我', '提出', '301', '是']
# ['应该', '按', '188', '元', '计费']
# ['但', '当班', '的', '位', '长发', '服务员', '极其', '傲慢', '地', '对', '我', '说', '：', '“', '小姐']
# ['那', '是', '不', '可能', '的']
# ['301', '就', '是']
# ['”', '对', '我', '我', '提出', '为何', '同', '是']
# ['和', '床', '的', '大小', '却', '有', '如此', '大', '的', '区别', '时']
# ['对方', '声称']
# ['的', '电视', '是', '液晶', '的']
# ['而', '是非', '液晶', '电视']
# ['301', '的', '电视', '就', '是', '液晶', '的']
# ['但是', '我', '分明', '看到', '该', '酒店', '的', '电梯', '里', '贴', '的', '画报', '电视', '是', '液晶', '的']
# ['小姐', '说', '：', '“', '那', '可能', '是', '画报', '弄', '错', '了']
# ['”', '对于', '这样', '的', '强词夺理']
# ['我', '提出', '请', '你们', '的', '经理', '出', '来', '和', '我', '解释']
# ['长发', '服务员', '不', '的', '对', '我', '说', '：', '“', '今天', '是', '周日']
# ['我们', '领导', '都', '休息']
# ['”', '住', '过', '这', '多', '的', '宾馆']
# ['遇到', '这样', '的', '还', '真', '的', '是', '第一', '次']
# ['僵持', '了', '二十', '分钟', '这', '后']
# ['另', '短发', '服务员', '称', '请示', '了', '领导', '之后']
# ['同意', '301', '房', '以', '208', '元', '的', '价格']
# ['我', '不', '想', '为', '了', '20', '元', '钱', '而', '再', '浪费', '时间']
# ['最后', '很', '心平气和', '地', '告诉', '她们', '：', '“', '你们', '得到', '的', '是', '20', '元', '钱']
# ['但', '你们', '失去', '的', '是', '诚信']
# ['是', '品牌']
# ['是', '服务']
# ['是', '客户']
# ['”', '另外', '要', '补充', '的', '是']
# ['酒店', '早餐', '极', '差']
# ['本', '想', '喝', '杯', '牛奶']
# ['还是', '奶粉', '兑', '的']
# ['不', '得', '不', '又', '跑', '到', '附近', '的', '肯德基']
# ['晚上', '11点']
# ['电话', '铃声', '会', '准时', '响起']
# ['“', '先生']
# ['你', '需要', '按摩', '吗']
# ['”', '的', '门铃', '不', '会', '响']
# ['床头灯', '不', '会', '亮']
# ['再', '不', '会', '入住', '这', '家', '酒店', '了']
# ['还有', '我', '是', '在', '交易会', '期间', '入住', '的']
# ['408', '天']
# ['就', '成', '这个', '样子', '了']
# ['现在', '服务', '水平', '很', '差']
# ['是', '老', '上海', '身份', '的', '象征']
# ['可是']
# ['这样', '的', '酒店', '怎', '会', '有', '这', '差', '的', '服务']
# ['我', '是', '上海', '人']
# ['帮', '我', '的', '客人', '订', '的', '酒店']
# ['这样', '的', '服务', '这样', '的', '反应', '速度']
# ['这样', '草率', '敷衍', '的', '服务', '质量']
# ['实在', '无言以对']
# ['以后', '不', '会', '订', '他们', '了']
# ['给', '我们', '的', '三亚', '之', '旅', '留下', '了', '非常', '好', '的', '印象']
# ['环境', '优美', '宁静']
# ['服务', '热情', '周到']
# ['下次', '去', '一定', '还', '住']
# ['希望', '那时', '的', '餐饮', '能', '再', '丰富', '多样', '些']
# ['我', '住', '的', '是', '贵宾楼']
# ['就', '是', '2', '号', '楼', '(', '其他', '楼', '不', '知道', ')']
# ['设施', '和', '环境', '甚至', '比', '某些', '都', '好']
# ['但', '早餐', '般']
# ...
# ['简直', '使', '人', '入睡']
# ['可以', '上网']
# ['但', '使用']
# ['不', '知道', '当初', '李鹏', '会', '给', '这个', '酒店', '题词']
# ['实在', '是', '误导', '大', '家']
# ['不', '明白', '这个', '酒店', '怎', '会', '是', '四星级']
# ['强烈', '建议', '取消', '这个', '酒店']
# ['很', '不', '错']
# ['风景', '很', '好']
# ['交通', '很', '方便']
# ['设施', '很', '齐全']
# ['挺', '满意']
# ['中午', '1点', '多', '到达', '酒店']
# ['前台', '小姐', '因为', '准备', '好']
# ['而', '欺骗', '我们', '放弃', '原定', '每晚', '1000', '多', '一点', '的', '房费']
# ['追加', '几百', '块']
# ['提升', '到', '每晚', '1400', '左右']
# ['假', '的', '说', '那样', '就', '可以', '享受', '免费', '咖啡']
# ['后', '来', '被', '我', '识破', '是', '因为', '我', '没', '原定', '的', '后']
# ['小姐', '态度', '变', '得', '很', '糟糕']
# ['副', '不', '的', '样子']
# ['很', '让', '人', '生气']
# ['没', '准备', '好']
# ['给', '客人', '免费', '升级', '是', '惯例']
# ['第一', '次', '遇到', '这样', '欺骗', '客人', '付费', '升级', '的', '酒店']
# ['以后', '再', '不', '会', '入住']
# ['楼下', '的', '两岸', '咖啡']
# ['极为', '不', '地道']
# ['早餐', '品种', '很', '少']
# ['绝对', '不', '能', '说是', '5', '星', '标准']
# ['太', '差', '了']
# ['的']
# ['而且', '上网', '及其', '不', '方便']
# ['甚至', '根本', '不', '能', '上']
# ['服务', '的', '态度', '很', '差']
# ['我', '入', '住', '的', '是', '豪华']
# ['很', '宽敞']
# ['尤其', '是', '卫生间']
# ['非常', '大']
# ['有', '独立', '的', '淋浴', '间']
# ['的', '装饰', '格局', '很', '有', '特色']
# ['充满', '着', '浓郁', '的', '西藏', '风格']
# ['该', '酒店', '的', '服务', '很', '好']
# ['非常', '热情']
# ['这', '次', '五一', '先后', '两', '次', '入住', '该', '酒店']
# ['恰巧', '是', '格局', '不', '同', '的', '两', '间']
# ['不', '仅', '风格', '一致']
# ['而且', '各有千秋']
# ['都']
# ['要', '说', '缺点']
# ['可能', '就', '是', '的', '市中心', '有', '距离']
# ['出租', '车费', '就', '10', '元', '左右']
# ['是', '家', '很', '不', '错', '的', '酒店']
# ['性', '价', '比', '很', '高']
# ['下次', '来', '还', '会', '选择', '它']
# ['环境', '很', '不', '错', '的', '酒店']
# ['只', '是', '各位', '若', '要', '去', '泡', '温泉']
# ['记得', '自己', '带', '游泳衣', '哦', '~', '~', '~', '最', '值得一提', '的', '是']
# ['酒店', '的', '很', '大']
# ['里', '简直', '是', '2', '个']
# ['睡', '4', '个', '人', '绝对', '问题', '的', '~', '~', '~', '呵呵']
# ['总体', '感觉', '还是', '不', '错', '的']
# ['除', '了', '在', '堂', '不', '够', '气派', '以外']
# ['价', '格', '有些', '贵']
# ['下次', '还', '会', '入', '住', '该', '酒店']
# ['住房', '舒适']
# ['比较', '大', '的']
# ['床', '比', '般', '的', '大']
# ['睡', '的', '比较']
# ['早餐', '不错', '．']
# ['2月', '4日', '入', '住', '普通']
# ['楼']
# ['1', '：', '地毯', '很', '脏']
# ['到处', '污点', '斑斑']
# ['到处', '是', '沾', '着', '头发', '和', '毛']
# ['2', '：', '很', '重']
# ['3', '：', '隔音', '效果', '差']
# ['深夜', '不', '断']
# ['4', '：', '空调', '不', '管用']
# ['挺', '冷']
# ['5', '：', '睡袍']
# ['6', '：', '烧', '开水', '的', '壶', '很', '脏']
# ['通过', '了', '2', '个']
# ['结果', '到', '了', '酒店']
# ['酒店', '前台', '告诉', '我', '订', '的', '是', '1', '个', '和', '1', '个']
# ['强烈', '交涉', '后']
# ['酒店', '还是', '给', '了', '我', '2', '个']
# ['但是', '设施', '极', '差']
# ['进', '房门', '就', '有', '浓重', '的', '和', '臭味']
# ['电视', '是', '坏', '的']
# ['的', '被子']
# ['不', '得', '不', '把', '空调', '开', '到', '最', '大']
# ['柜子', '里', '塞', '满', '了', '枕头', '却', '被子']
# ['洗手间', '的', '下水', '不', '畅']
# ['洗', '个', '澡', '还', '堵', '得', '地上', '都', '是', '水', '…', '…', '唯一', '值得一提', '的', '是', '早', '还', '不', '错']
# ['总结', '如下', '：', '1']
# ['有', '问题']
# ['已经', '跟', '我', '2', '个']
# ['但是', '到', '了', '酒店', '却', '变成', '1', '单', '间', '1', '；', '2']
# ['该', '酒店', '条件', '太', '差']
# ['根本', '不', '符合', '三星级', '标准']
# ['不', '建议', '入住']
# ['酒店', '大堂', '十分', '温馨', '、', '典雅']
# ['食物', '非常', '可口']
# ['连', '早餐', '的', '选择', '都', '和', '晚餐', '一样', '丰富']
# ['服务员', '的', '英语', '都', '不', '错']
# ['关键', '是', '入', '住', '客人', '感到', '周围', '环境', '十分', '好']
# ['于', '繁华', '商业街', '之上']
# ['这次', '的', '停留', '十分', '满意']
# ['望', '再接再厉']
# ['机场', '接送', '比较', '好']
# ['环境', '挺', '好', '的']
# ['服务', '都', '不', '错']
# ['有', '机会', '还', '会', '再', '住']
# ['性', '价', '比', '不', '错', '的', '酒店']
# ['这次', '住', '的', '是', '主楼', '的']
# ['真是', '不', '错']
# ['很', '大', '而且', '里', '都', '是', '红木', '家', '具']
# ['这', '在', '上海', '酒店', '中', '可能', '是', '仅', '有', '的', '吧']
# ['真是', '既', '有', '气派', '很', '有', '老', '上海', '的']
# ['看', '来', '是', '花', '了', '大', '心血', '的']
# ['从', '窗户', '看', '出去', '花园', '很', '漂亮']
# ['地段', '更', '不', '了']
# ['是']
# ['以后', '再', '去', '上海', '就', '住', '那里', '了']
# ['此', '酒店', '入住', '环境', '太', '差']
# ['同', '价', '位', '的', '酒店', '不', '建议', '入', '驻', '；', '开车', '的', '人', '不', '要', '入', '驻']
# ['没', '地', '停车']
# ['此', '酒店', '寻找', '起', '来', '不']
# ['大', '家', '都', '知道', '“', '观', '前', '街', '”']
# ['不', '知道', '“', '观', '后', '街', '”', '：', '（']
# ['地理', '位置', '不', '错']
# ['有点', '旧']
# ['服务', '态度', '良好']
# ['总体', '感觉', '不', '错']
# ['软硬件', '都', '非常', '好']
# ['超值']
# ['可以', '说是', '最', '好', '的', '五星级', '酒店', '了']
# ['不好意思']
# ['刚才', '的', '点评', '是', '指', '的', '北京', '南京', '大酒店']
# ['杭州', '宾馆', '非常', '不', '错']
# ['距离', '西湖', '非常', '近']
# ['步行', '至', '断', '桥', '只', '需要', '到', '十', '分钟']
# ['交通', '方便']
# ['出', '酒店']
# ['过', '街', '就', '有', '公共', '汽车站']
# ['好多', '旅游车', '可以', '还', '到', '去', '不', '同', '的', '景点']
# ['特别', '是', '早上', '的', '七', '楼', '的']
# ['非常', '漂亮']
# ['可以', '远眺', '西湖', '景色']
# ['而且', '非常', '不', '错']
# ['舒适']
# ['有', '窗户']
# ['可以', '通风']
# ['有', '宽带']
# ['是', '性', '价', '比', '非常', '高', '的', '酒店']
# ['个人', '非常', '喜欢']
# ['下次', '来', '杭州', '还', '在', '住', '在', '这里']
# ['这种', '饭店', '还', '能', '评', '3', '星']
# ['简直', '就', '是', '坑人']
# ['服务', '很', '差']
# ['松', '了', '让', '客房', '服务']
# ['服务', '小姐', '居然', '说']
# ['我', '手上', '都', '已经', '没劲', '了']
# ['你', '就', '不', '能', '自己', '掰', '一下']
# ['其二']
# ['晚上', '敲门']
# ['因为', '小孩', '睡着', '了']
# ['很', '小声', '地', '回答']
# ['并', '起身', '去', '开门']
# ['居然', '服务', '小姐', '自己', '用', '直接', '将门', '打开']
# ['晕倒']
# ['酒店', '设施', '差']
# ['浴缸', '是', '破', '的']
# ['马桶', '有点', '堵塞']
# ['的', '鬼火']
# ['本', '来', '以为', '是', '2005年', '开业', '的', '应该', '很', '新']
# ['实际', '真', '的', '很', '糟糕']
# ['酒店', '环境', '差']
# ['住', '的', '朝', '南面', '的']
# ['对面', '是']
# ['真', '吵', '啊']
# ['车辆', '过夜']
# ['还要', '收', '停车费']
# ['豪华', '空间', '特大']
# ['床', '特别', '宽']
# ['室内', '卫生', '搞', '得', '不', '错']
# ['总体', '感觉', '不', '错']
# ['此次', '入住', '重庆', '万豪']
# ['感觉', '非常', '好']
# ['地理', '位置', '位于', '重庆', '市中心']
# ['购物', '吃饭', '均', '很', '方便']
# ['房', '价', '性', '价', '比', '很', '高']
# ['酒店', '服务', '好']
# ['我', '漏掉', '了', '我', '的', '西装', '上衣']
# ['已经', '过去', '3', '了', '天']
# ['我', '才', '发现']
# ['的', '小姐', '很快', '找到']
# ['快递', '回', '上海']
# ['非常', '感激']
# ['酒店', '位置', '话', '说']
# ['稍', '小']
# []
# ['另外']
# ['有', '位', '非常', '漂亮', '的', '女']
# ['每', '次', '都', '微笑', '地', '问好']
# ['不', '错']
# ['我', '想', '要', '说', '的', '是', '上网', '问题']
# ['当时', '我', '正好', '有', '急事']
# ['必须', '上网', '与', '国外', '联系']
# ['可是', '服务员', '让', '我', '抱', '着', '电脑', '挨', '个', '试']
# ['就是', '家', '能', '上']
# ['让', '我', '非常', '郁闷']
# ['宽敞']
# ['洗浴', '设备', '齐全']
# ['就餐', '环境', '好']
# ['管', '家', '服务', '周到']
# ['各种', '旅游', '延伸', '服务', '（', '自助', '）', '完善']
# ['珠海', '大酒店', '的', '员工', '素质', '不', '错']
# ['且', '服务', '态度', '友好']
# ['处理', '问题', '的', '效率', '比较', '高']
# ['感觉', '还是', '不', '错', '的']
# ['Front', 'service', 'i', 's', 'not', 'good']
# ['这', '是', '我', '常常', '入', '住', '的', '间', '酒店']
# ['我', '十分', '喜欢']
# ['不', '过']
# ['这', '次', '入住']
# ['床头柜', '指示', '的', '电子', '时钟', '整整', '了', '近', '20', '分钟']
# ['当天', '我', '约', '了', '司机', '准时', '来', '接', '我']
# ['其实', '是', '时钟', '了']
# ['狠狠', '地', '批评', '司机', '守', '时']
# ['这', '件', '事', '我', '在', '前台', '时', '跟', '他们', '说', '过']
# ['希望', '改正']
# ['服务员', '的', '态度', '十分', '好']
# ['连', '说', '抱歉']
# ['不', '过']
# ['我', '还是', '给', '大', '家', '推荐', '这', '家', '酒店']
# ['很', '传统', '的', '好', '酒店']
# ['所以', '我', '的', '会员', '评分', '仍旧', '全', '给', '5', '分']
# ['此', '酒店', '刚', '装修', '完']
# ['有', '较', '强', '的', '异味']
# ['作为', '四星级', '的', '酒店', '冰箱']
# ['所谓', '的', '宽带', '不通', '（', '服务员', '说', '：', '是', '电信局', '的', '事', '）']
# ['酒店', '的', '旁边', '有', '个', '车间']
# ['焊接', '和', '切割', '一些']
# ['白天', '制造', '很', '大', '的', '噪声']
# ['让', '你', '休息']
# ['虽然', '我', '在', '你们', '的', '网站', '上', '订', '了', '许多', '酒店']
# ['可', '这', '是', '我', '第一', '次', '在', '网上', '评述']
# ['真', '的', '般']
# ['我', '还', '以为', '是', '那个', '河畔', '酒店', '呢']
# ['春节', '时', '住', '了', '海天']
# ['机场', '大巴', '就', '在', '楼下']
# ['酒店', '环境', '不', '错']
# ['非常', '热']
# ['但', '美中不足']
# ['的', '了', '一些']
# ['所谓', '的', '海景', '是', '侧面', '看', '海']
# ['只', '提供', '了', '单人', '单日', '早餐']
# ['感觉', '不', '是', '很', '爽']
# ['非常', '好', '的', '酒店']
# ['性', '价', '比', '很', '高']
# ['酒店', '很', '干净']
# ['做', '得', '很', '好']
# ['我', '预定', '的', '时候', '还', '担心', '怎', '样']
# ['就', '是', '158', '元', '的', '价格', '才', '吸引', '了', '我']
# ['但', '到', '了', '酒店', '这', '后']
# ['这种', '疑虑', '立刻', '消除', '了']
# ['酒店', '的', '整个', '布局', '除', '了', '继续', '保持', '美国', '的', '标准', '外']
# ['又', '有', '苏州', '本地', '的', '特色']
# ['真', '不', '国际', '品牌', '连', '锁', '酒店']
# ['我', '下次', '一定', '还', '会', '选择', '速']
# ['依我看', '来']
# ['苏州', '的', '如', '家', '、', '小心', '了']
# ['嘿嘿']
# ['又', '多', '了', '强大', '的', '对手']
# ['很', '好']
# ['很', '干净']
# ['离', '闹市', '比较', '近']
# ['卫生间', '里', '是', '淋浴', '的']
# ['很', '方便']
# ['酒店', '环境', '优越']
# ['服务', '周到']
# ['宾至如归']
# ['酒店', '大堂', '高贵']
# ['豪华']
# ['略', '有', '王者', '风范']
# ['我们', '每天', '订']
# ['就', '不', '水果', '、', '咖啡']
# ['网上', '有', '果盘', '的']
# ['简直', '不', '讲', '道理']
# ['优点', '就', '不', '说', '了']
# ['说说', '缺点', '吧']
# ['1', '、', '前台', '的', 'POS', '的', '该', '换换', '了']
# ['刷', '慢', '的', '出奇']
# ['1', '、', '前台', '服务员', '态度', '不', '是', '很', '好']
# ['3', '、']
# ['最', '要命', '的', '缺点']
# ['宾馆', '主要', '的', '功能', '时', '能', '提供', '相对', '安静', '的', '环境']
# ['可是', '住', '在', '这里', '实在', '吵', '得', '要', '命']
# ['联系', '前台', '提出', '置之不理']
# ['4', '、', '全天', '的', '暖气']
# ['实在', '搞笑']
# ['问', '前台', '说', '要', '五点', '以后', '才', '提供']
# ['这样', '的', '大酒店', '我', '想', '和', '小', '旅社', '都', '有', '区别']
# ['小', '旅社', '还', '提供', '24', '小时', '暖气', '呢']
# ['真', '的', '搞笑']
# ['八月份', '和', '朋友', '一起', '去', '重庆', '看', '房']
# ['入住', '希尔顿', '真', '是', '种', '缘份']
# ['虽然', '是', '雨天']
# ['但是', '影响', '心情']
# ['觉得', '非常', '超值']
# ['（', '正好', '是', '活动月']
# ['398', '元', '周末', '中', '宾', '特', '价']
# ['住', '过', '性', '价', '比', '最', '好', '的', '五星级', '）', '优点', '：', '1', '、', '新', '而且', '大']
# ['本人', '最', '关注', '的', '浴室', '、', '床', '都', '非常', '舒适']
# []
# ['要', '新']
# ['至少', '在', '和', '地毯', '上']
# ['2', '、', '窗台', '是', '落地', '大', '窗']
# ['灯光', '很', '温馨']
# ['3', '、', '电梯', '很', '大']
# ['很', '高']
# ['前台', '服务']
# ['比较', '得体']
# ['服务', '人员', '比较', '有', '朝气']
# ['美中不足', '：', '酒店', '入口', '在', '比较', '难', '找']
# ['大堂', '进去', '不', '够', 'J']
# ['气派']
# ['不', '够', '高']
# ['地段', '稍', '差', '一点']
# ['稍', '晚', '出', '来', '不好', '找', '吃', '的']
# ['看', '来', '重庆', '真', '的', '在', '进步']
# ['楼下', '的', '都', '说', '过', '了']
# ['没', '什', '可', '多', '说', '的', '了']
# ['我', '对', '国际', '会展', '酒店', '非常', '非常', '满意']
# ['环境', '和', '设施', '都', '很', '不', '错']
# ['很', '干净']
# ['价', '合理', '~', '~', '~', '这个', '价', '位', '在', '深圳', '已经', '很', '不', '错', '了']
# ['1']
# ['所谓']
# ['看', '不', '到', '海景']
# ['原因', '：', '要', '就', '是', '位置', '根本', '不', '对']
# ['要', '把', '头', '伸', '出去', '扭转', '180', '往后', '看', '才', '能', '看到', '；', '要', '就', '是', '太', '脏']
# ['而', '整个', '只', '有', '半', '扇', '窗', '能', '开']
# ['要', '看', '窗上', '的', '灰尘']
# ['要', '打开', '窗', '看', '条', '缝']
# ['2']
# ['卫生', '很', '差']
# ['洗手间', '的', '3', '个', '烟', '屁股', '从', '进', '到', '离开']
# ['3', '天', '一直', '清理', '掉']
# ['连', '位置', '都', '不', '曾', '变', '过']
# ['故', '不', '理解', '服务员', '的', '整理', '为', '何物']
# ['马桶', '的', '黄色', '污物', '熟视无睹']
# ['马桶', '的', '抽水', '有', '问题']
# ['垃圾桶', '只', '清理', '大件', '垃圾']
# ['小', '垃圾', '如', '餐巾纸']
# ['小', '包装袋', '等', '不', '清理']
# ['（', '注', '：', '偶', '们', '住', '的', '是', '高级', '海景', '间']
# ['不', '是', '最', '便宜', '的', '）', '3']
# ['没', '找到', '4']
# ['隔音', '很', '差']
# ['汗']
# ['5']
# ['我们', '在', '26', '楼']
# ['窗', '总是']
# ['恐惧']
# ['6']
# ['床', '上', '垫', '得', '很', '少']
# ['很', '不']
# ['被子', '很', '薄']
# ['被', '套', '和', '被', '不']
# ['7']
# ['午餐', '和', '晚餐']
# []
# ['服务', '态度', '不', '好']
# ['服务', '很', '差']
# ['设施', '很', '旧', '不', '算']
# ['骚扰', '电话', '太', '多']
# ['酒店', '对', '自', '驾车', '的', '还要', '收', '10', '元', '停车费']
# ['这个', '价', '钱', '住', '这种', '酒店', '不', '值']
# ['酒店', '的', '位置', '很', '好']
# ['步行', '到', '南京路', '步行街', '2', '分钟']
# ['到', '外滩', '10', '分钟']
# ['价', '格', '合理']
# ['旁边', '的', '酒店', '1500', '元', '宿']
# ['这里', '480', '元', '宿']
# ['的', '设施', '考虑', '很', '周全']
# ['免费', '上网']
# ['有', '微波炉']
# ['有', '雨伞', '等']
# ['好']
# ['有', '信誉']
# ['非常', '好', '的', '酒店']
# ['值得', '推荐']
# ['的', '布置', '很']
# ['尤其', '是', '洗手间']
# ['是', '全', '透明', '的']
# ['洗手间', '里', '的', '一次性', '用品', '做', '得', '很', '齐全', '和', '精致']
# ['早餐', '非常', '丰富']
# ['大堂', '里', '还有', '酒', '吧']
# ['服务', '真', '的', '很', '差']
# ['完全', '服务', '意识']
# ['和', '内地', '的', '大多数', '酒店', '没', '什', '区别', '；', '很', '差']
# ['进入', '后', '有', '很', '强烈', '发霉', '的']
# ['我', '住', '的', '窗帘', '根本', '拉', '不', '上']
# ['有', '非常', '大', '的', '缝隙']
# ['让', '酒店', '马上', '给', '我', '换', '间']
# ['居然', '费', '了', '很', '大', '的', '周折']
# ['有点儿', '在', '北京', '办事', '的']
# ['恍然', '间', '好像', '知道', '叫', '“', '酒店', '”', '了']
# ['带', '了', '一些', '行李']
# ['本', '来', '以为', '行李', '工会', '像', '其他', '酒店', '一样', '主动', '为', '你', '拿', '行李']
# ['我', '本', '打算', '给', '20', '元', '小费']
# ['没', '几', '个', '居然', '主动', '为', '我', '拿', '行李']
# ['有', '点儿', '可笑']
# ['对面', '有', '个', '小', '超市']
# ['步行', '到', '葡', '京', '不', '是', '很', '远']
# ['因为', '本身', '澳门', '就', '很', '小']
# ['不', '好']
# ['服务', '态度', '差']
# ['出现', '问题']
# ['酒店', '首先', '逃避']
# ['十分', '的', '不', '满意']
# ['住', '了', '天', '就', '换', '了']
# ['很', '的', '酒店']
# ['就', '在', '第一', '海水']
# ['走', '出', '酒店', '就', '是', '海']
# ['还有', '无敌', '海景']
# ['美丽', '啊']
# ['自助餐', '旋转', '餐厅', '很', '棒', '下次', '尝试', '去', '海天', '酒店']
# ['so', 'small']
# ['the', 'food', 'i', 's', 'terrible']
# ['also', 'the', 'staff', 'o', 'f', 'the', 'i', 's', 'bad']
# ['我', '是', '1月', '底', '去', '哈尔滨', '旅游', '的']
# ['说', '句', '实在', '话']
# ['哈尔滨', '给', '我', '的', '印象', '了']
# ['在', '这里', '评论']
# ['是', '想', '方便', '后', '来', '的', '朋友', '有', '客观', '的', '心理', '预期']
# ['说', '酒店', '吧', '：', '我', '是', '在', '上', '反复', '查看', '酒店', '评论', '中', '的']
# ['但', '到', '了', '之后', '发现']
# ['简直', '是', '恶', '梦', '：', '1', '、', '我', '定', '的', '是', '贵宾楼', '（', '据说', '贵宾楼', '比', '好', '）']
# ['入', '住', '当', '说', '因为', '某些', '原因']
# ['免费', '给', '我们', '升级', '到', '的', '套房']
# ['我', '虽然', '知道', '不', '好']
# ['但', '为', '了', '配合', '酒店', '工作', '就', '答应', '了']
# ['跟着', '服务员', '转', '了', '十', '分钟', '终于', '到', '了']
# ['进', '门']
# ['发现', '里', '地面', '上', '铺', '着', '张', '又', '烂', '又', '脏', '的']
# ['空气', '中', '还', '弥漫', '着', '浓浓', '的']
# ['的', '门', '坏', '了']
# ['打开', '之后', '竟然', '关', '不', '上']
# ['叫', '服务员', '来', '修']
# ['大概', '二十', '多', '分钟', '才', '过', '来']
# ['躺', '在', '床', '上', '半', '个', '小时']
# ['竟然', '被', '烟', '味', '熏', '的', '呕吐', '起', '来']
# ['实在', '受', '不', '了']
# ['要求', '服务员', '换']
# ['2', '、', '如果', '说', '个别', '现象']
# ['但', '装修', '味', '就', '是', '普遍', '现象', '了']
# ['住', '在', '那里', '两', '天']
# ['被', '装修', '污染', '熏', '了', '两', '天']
# ['设施', '极其', '陈旧']
# ['3', '、', '服务员', '素质', '差']
# ['服务', '态度', '不', '好']
# ['真', '的', '让', '我', '受', '不', '了']
# ['4', '、', '早餐', '品种', '少']
# ['不', '卫生']
# ['大', '冬天', '的', '还有', '苍蝇', '飞', '来', '飞', '去']
# ['5']
# ['服务员', '竟然', '和', '黑车', '司机', '串通']
# ['在', '我们', '离开', '酒店', '的', '时候']
# ['先是', '向', '我们', '要', '高', '价']
# ['然后', '出', '酒店', '门', '就', '给', '我们', '换', '到', '另', '辆', '车上']
# ['在', '上', '到', '高速', '路边', '时', '竟然', '强行', '又', '让', '我们']
# ['是', '和', '别人']
# ['哈尔滨', '的', '旅游业']
# ['如此', '下去']
# []
# ['I', 'forgot', 'm', 'y', 'identity', 'card', 'o', 'n', 'the', 'desk', 'i', 'n', 'the', 'room']
# ['I', 'call', 'them', 't', 'o', 'check', 'they', 'said', 'no']
# ['finally', 'm', 'y', 'friend', 'g', 'o', 't', 'o', 'the', 'room', 't', 'o', 'check', '&', 'amp', ';', 'find', 'i', 't', 'o', 'n', 'the', 'desk']
# ['I', 'was', 's', 'o', 'disappointed', 'for', 'the', 'services']
# ['此地', '很', '差']
# ['破破烂烂']
# ['工作', '人员', '无知', '无', '礼貌', '典型', '北京', '作风']
# ['保洁', '人员', '糊弄', '事', '每天', '打扫', '只用', '2', '分钟']
# ['但是', '亚运村', '环境', '非常', '好', '（', '除', '了', '例行', '堵车', '）']
# ['这', '家', '酒店', '是', '我', '见', '过', '酒店', '中', '最', '差', '的']
# ['我', '住', '过', '很多', '宾馆']
# ['但是', '面对', '这样', '遭遇', '还', '是', '第一', '次']
# ['这', '家', '酒店', '小']
# ['服务', '质量', '真是', '极', '差']
# ['上网', '拿']
# ['还要', '10', '元']
# ['而且', '酒店', '做', '不', '了']
# ['要', '买', '单']
# ['再', '交', '押金']
# ['而且', '前台', '服务', '态度', '非常', '恶劣']
# ['是', '你', '欠', '钱', '似', '的']
# ['哎']
# ['大', '家', '最好', '是', '不', '要', '订', '这', '家', '酒店']
# ['不', '然', '肯定', '后悔']
# ['刚刚', '接到', '的', '电话']
# ['就', '我', '入', '住', '遇到', '的', '一些', '问题', '主动', '与', '酒店', '进行', '了', '沟通']
# ['双方', '都', '比较', '重视']
# ['并', '向', '我', '表达', '了', '歉意']
# ['酒店', '表示', '以后', '会', '注意', '类似', '的', '问题']
# ['并', '邀请', '我', '今后', '再次', '入住']
# ['和', '酒店', '的', '态度', '令', '我', '比较', '满意']
# ['希望', '今后', '避免', '此类', '现象', '再次', '发生']
# ['并', '对', '及', '酒店', '的', '重视', '表示', '感谢']
# ['不', '错']
# []
# ['要是', '能', '提供', '免费', '宽带', '接', '入', '就', '更', '好', '了']
# ['非常', '不', '错', '的', '宾馆']
# ['交通', '很', '便利']
# ['地段', '很', '好']
# ['不', '错']
# ['早餐', '很', '丰富']
# ['总', '的', '来说', '很', '好']
# ['唯一', '不', '足', '的', '地方', '就', '是', '空调', '不', '够', '大']
# ['希望', '以后', '能', '进一步', '改进']
# ['硬件', '太', '差']
# ['不', '畅']
# ['淋浴', '的', '可怜']
# ['还', '不', '热']
# ['冻', '的', '够呛']
# ['换', '了', '依旧']
# ['另外']
# ['隔音', '效果', '不', '好']
# ['大清早', '就', '被', '外面', '的']
# ['最近', '在', '装修']
# []
# ['很', '吵']
# ['设施', '较', '陈旧']
# ['感觉', '现在', '不', '配', '三星']
# ['前', '街', '走路', '5', '分钟']
# ['去', '15', '块']
# ['很', '方便']
